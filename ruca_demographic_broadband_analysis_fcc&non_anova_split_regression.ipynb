# %% [markdown]
# ### Analysis of Variance on broadband availability for regression feature selection
#
#
# * All residential blocks in contiguous U.S. with complete data are considered, for year 2018
# * Using ANOVA correlations for numerical input, categorical output (see https://machinelearningmastery.com/feature-selection-with-real-and-categorical-data/)
# * helpful visualization for ANOVA correlations, showing why higher is better: https://datascience.stackexchange.com/questions/74465/how-to-understand-anova-f-for-feature-selection-in-python-sklearn-selectkbest-w
#
#
# #### Outline:
#    1. data import
#    2. Analysis of Variance (ANOVA) on contiguous U.S.
#    3. ANOVA on RUCA categories

# %% [markdown]
# #### 1. data import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest # for selecting variables based on criteria
from sklearn.feature_selection import f_classif # for ANOVA correlation

# %%
df=pd.read_csv('fcc477_2018_grouped_ruca_demographic_byblock_with_social_variables_with_DC.csv') 
df.info()
df.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (57,58,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8254631 entries, 0 to 8254630
# Columns: 101 entries, BlockCode to Violent Crimes p 100,000
# dtypes: float64(69), int64(18), object(14)
# memory usage: 6.2+ GB
#         BlockCode  NumberOfUniqueProviderNames  NumberOfUniqueHocoNums  \
# 0  10010201001000                            3                       3
# 1  10010201001001                            1                       1
# 2  10010201001002                            2                       2
# 3  10010201001003                            2                       2
# 4  10010201001004                            1                       1
#
#    MeanMaxAdDown  MeanMaxAdUp  SdMaxAdDown  SdMaxAdUp  \
# 0     592.800000       27.256   530.777920  25.056957
# 1     940.000000       35.000          NaN        NaN
# 2     317.333333       12.008   539.245151  19.911656
# 3     319.333333       12.008   537.521472  19.911656
# 4     940.000000       35.000          NaN        NaN
#
#    NumberOfUniqueTechCodes        GIDBG  \
# 0                        5  10010201001
# 1                        1  10010201001
# 2                        3  10010201001
# 3                        3  10010201001
# 4                        1  10010201001
#
#    State-County-Tract FIPS Code (lookup by address at http://www.ffiec.gov/Geocode/)  \
# 0                                         1001020100
# 1                                         1001020100
# 2                                         1001020100
# 3                                         1001020100
# 4                                         1001020100
#
#    ...  % births to unmarried women  % women currently married  \
# 0  ...                         29.6                       65.2
# 1  ...                         29.6                       65.2
# 2  ...                         29.6                       65.2
# 3  ...                         29.6                       65.2
# 4  ...                         29.6                       65.2
#
#    % children with single parent  \
# 0                           22.4
# 1                           22.4
# 2                           22.4
# 3                           22.4
# 4                           22.4
#
#    Non-religious non-profit organizations p 1,000  \
# 0                                             2.2
# 1                                             2.2
# 2                                             2.2
# 3                                             2.2
# 4                                             2.2
#
#    Religious congregations p 1,000  Informal Civic Engagement Subindex  \
# 0                              1.9                           -1.032341
# 1                              1.9                           -1.032341
# 2                              1.9                           -1.032341
# 3                              1.9                           -1.032341
# 4                              1.9                           -1.032341
#
#    Presidential election voting rate, 2012 & 2016  \
# 0                                            60.5
# 1                                            60.5
# 2                                            60.5
# 3                                            60.5
# 4                                            60.5
#
#    Mail-back census response rate  Confidence in Institutions Subindex  \
# 0                            78.0                             0.208587
# 1                            78.0                             0.208587
# 2                            78.0                             0.208587
# 3                            78.0                             0.208587
# 4                            78.0                             0.208587
#
#    Violent Crimes p 100,000
# 0                     265.7
# 1                     265.7
# 2                     265.7
# 3                     265.7
# 4                     265.7
#
# [5 rows x 101 columns]

# %% [markdown]
# Make categories based on RUCA code:

# %%
conditions = [(df['Primary RUCA Code 2010']==1) | (df['Primary RUCA Code 2010']==4) | (df['Primary RUCA Code 2010']==7) ,\
             (df['Primary RUCA Code 2010']==2) | (df['Primary RUCA Code 2010']==5) | (df['Primary RUCA Code 2010']==8), \
             (df['Primary RUCA Code 2010']==3) | (df['Primary RUCA Code 2010']==6) | (df['Primary RUCA Code 2010']==9), \
             (df['Primary RUCA Code 2010']==10) | (df['Primary RUCA Code 2010']==99)]
values = [1,2,3,4] # 1 = core, 2 = suburb, 3 = exurb, 4 = rural
df['ruca_cat'] = np.select(conditions, values)
df.head()
# Out:
#         BlockCode  NumberOfUniqueProviderNames  NumberOfUniqueHocoNums  \
# 0  10010201001000                            3                       3
# 1  10010201001001                            1                       1
# 2  10010201001002                            2                       2
# 3  10010201001003                            2                       2
# 4  10010201001004                            1                       1
#
#    MeanMaxAdDown  MeanMaxAdUp  SdMaxAdDown  SdMaxAdUp  \
# 0     592.800000       27.256   530.777920  25.056957
# 1     940.000000       35.000          NaN        NaN
# 2     317.333333       12.008   539.245151  19.911656
# 3     319.333333       12.008   537.521472  19.911656
# 4     940.000000       35.000          NaN        NaN
#
#    NumberOfUniqueTechCodes        GIDBG  \
# 0                        5  10010201001
# 1                        1  10010201001
# 2                        3  10010201001
# 3                        3  10010201001
# 4                        1  10010201001
#
#    State-County-Tract FIPS Code (lookup by address at http://www.ffiec.gov/Geocode/)  \
# 0                                         1001020100
# 1                                         1001020100
# 2                                         1001020100
# 3                                         1001020100
# 4                                         1001020100
#
#    ...  % women currently married  % children with single parent  \
# 0  ...                       65.2                           22.4
# 1  ...                       65.2                           22.4
# 2  ...                       65.2                           22.4
# 3  ...                       65.2                           22.4
# 4  ...                       65.2                           22.4
#
#    Non-religious non-profit organizations p 1,000  \
# 0                                             2.2
# 1                                             2.2
# 2                                             2.2
# 3                                             2.2
# 4                                             2.2
#
#    Religious congregations p 1,000  Informal Civic Engagement Subindex  \
# 0                              1.9                           -1.032341
# 1                              1.9                           -1.032341
# 2                              1.9                           -1.032341
# 3                              1.9                           -1.032341
# 4                              1.9                           -1.032341
#
#    Presidential election voting rate, 2012 & 2016  \
# 0                                            60.5
# 1                                            60.5
# 2                                            60.5
# 3                                            60.5
# 4                                            60.5
#
#    Mail-back census response rate  Confidence in Institutions Subindex  \
# 0                            78.0                             0.208587
# 1                            78.0                             0.208587
# 2                            78.0                             0.208587
# 3                            78.0                             0.208587
# 4                            78.0                             0.208587
#
#    Violent Crimes p 100,000  ruca_cat
# 0                     265.7         1
# 1                     265.7         1
# 2                     265.7         1
# 3                     265.7         1
# 4                     265.7         1
#
# [5 rows x 102 columns]

# %% [markdown]
# Category distribution:

# %%
np.unique(df['ruca_cat'],return_counts=True)
# Out:
# (array([1, 2, 3, 4]), array([4632747, 2091370,  354439, 1176075]))

# %% [markdown]
# Filter out non-contiguous U.S. areas:

# %%
df_conus=df[(df['Select State']!='AK')& (df['Select State']!='HI')]
np.unique(df_conus['Select State']),len(np.unique(df_conus['Select State']))
# Out:
# (array(['AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'IA',
#         'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
#         'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY',
#         'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA',
#         'VT', 'WA', 'WI', 'WV', 'WY'], dtype=object),
#  49)

# %% [markdown]
# Numerical x & y dataframe:

# %%
df_conus_num=df_conus[['NumberOfUniqueProviderNames','NumberOfUniqueHocoNums',\
                       'NumberOfUniqueTechCodes','NumFCCEntriesWith25/3Speed','NumFCCEntriesWith100/10Speed',\
                       'AnyProviderWith25/3','AnyProviderWith100/10',
                       'MeanMaxAdDown','MeanMaxAdUp','Tot_Population_ACS_14_18', 'pct_URBANIZED_AREA_POP_CEN_2010',
       'pct_URBAN_CLUSTER_POP_CEN_2010', 'pct_RURAL_POP_CEN_2010',
       'avg_Tot_Prns_in_HHD_ACS_14_18', 'pct_Vacant_Units_ACS_14_18',
       'pct_Hispanic_ACS_14_18', 'pct_NH_White_alone_ACS_14_18',
       'pct_NH_Blk_alone_ACS_14_18', 'pct_NH_AIAN_alone_ACS_14_18',
       'pct_NH_Asian_alone_ACS_14_18', 'pct_NH_NHOPI_alone_ACS_14_18',
       'pct_NH_SOR_alone_ACS_14_18', 'pct_Othr_Lang_ACS_14_18',
       'pct_ENG_VW_ACS_14_18', 'pct_Not_HS_Grad_ACS_14_18',
       'pct_College_ACS_14_18', 'avg_Agg_HH_INC_ACS_14_18',
       'pct_Prs_Blw_Pov_Lev_ACS_14_18', 'pct_PUB_ASST_INC_ACS_14_18',
       'pct_Diff_HU_1yr_Ago_ACS_14_18', 'pct_Recent_Built_HU_ACS_14_18',
       'avg_Agg_House_Value_ACS_14_18','Primary RUCA Code 2010','Secondary RUCA Code, 2010 (see errata)', 'Tract Population, 2010',
       'Land Area (square miles), 2010',
       'Population Density (per square mile), 2010','rank','index','mobility_raw','pct_belowpov_raw',\
                      'pct_deeppov_raw','life_exp_raw','lbw_raw','urban','rural','reservation','city',\
                      'tot_pop','pct_lths','lfpr','pct_bachmore','County-Level Index', \
                       'Requiring all 4 Subindices', 'Excluding Collective Efficacy', 'Family Unity', \
                       'Community Health', 'Institutional Health', 'Collective Efficacy', \
                       '% births to unmarried women', '% women currently married', '% children with single parent', \
                       'Non-religious non-profit organizations p 1,000', 'Religious congregations p 1,000', \
                       'Informal Civic Engagement Subindex', 'Presidential election voting rate, 2012 & 2016', \
                       'Mail-back census response rate', 'Confidence in Institutions Subindex', 'Violent Crimes p 100,000','ruca_cat']]
# df_conus_num['teenbirthrate']=df_conus_num['teenbirthrate'].astype(float)  #doesn't work because has ''
df_conus_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8232809 entries, 0 to 8254630
# Data columns (total 70 columns):
#  #   Column                                          Dtype
# ---  ------                                          -----
#  0   NumberOfUniqueProviderNames                     int64
#  1   NumberOfUniqueHocoNums                          int64
#  2   NumberOfUniqueTechCodes                         int64
#  3   NumFCCEntriesWith25/3Speed                      int64
#  4   NumFCCEntriesWith100/10Speed                    int64
#  5   AnyProviderWith25/3                             int64
#  6   AnyProviderWith100/10                           int64
#  7   MeanMaxAdDown                                   float64
#  8   MeanMaxAdUp                                     float64
#  9   Tot_Population_ACS_14_18                        float64
#  10  pct_URBANIZED_AREA_POP_CEN_2010                 float64
#  11  pct_URBAN_CLUSTER_POP_CEN_2010                  float64
#  12  pct_RURAL_POP_CEN_2010                          float64
#  13  avg_Tot_Prns_in_HHD_ACS_14_18                   float64
#  14  pct_Vacant_Units_ACS_14_18                      float64
#  15  pct_Hispanic_ACS_14_18                          float64
#  16  pct_NH_White_alone_ACS_14_18                    float64
#  17  pct_NH_Blk_alone_ACS_14_18                      float64
#  18  pct_NH_AIAN_alone_ACS_14_18                     float64
#  19  pct_NH_Asian_alone_ACS_14_18                    float64
#  20  pct_NH_NHOPI_alone_ACS_14_18                    float64
#  21  pct_NH_SOR_alone_ACS_14_18                      float64
#  22  pct_Othr_Lang_ACS_14_18                         float64
#  23  pct_ENG_VW_ACS_14_18                            float64
#  24  pct_Not_HS_Grad_ACS_14_18                       float64
#  25  pct_College_ACS_14_18                           float64
#  26  avg_Agg_HH_INC_ACS_14_18                        float64
#  27  pct_Prs_Blw_Pov_Lev_ACS_14_18                   float64
#  28  pct_PUB_ASST_INC_ACS_14_18                      float64
#  29  pct_Diff_HU_1yr_Ago_ACS_14_18                   float64
#  30  pct_Recent_Built_HU_ACS_14_18                   float64
#  31  avg_Agg_House_Value_ACS_14_18                   float64
#  32  Primary RUCA Code 2010                          float64
#  33  Secondary RUCA Code, 2010 (see errata)          float64
#  34  Tract Population, 2010                          float64
#  35  Land Area (square miles), 2010                  float64
#  36  Population Density (per square mile), 2010      float64
#  37  rank                                            int64
#  38  index                                           float64
#  39  mobility_raw                                    float64
#  40  pct_belowpov_raw                                float64
#  41  pct_deeppov_raw                                 float64
#  42  life_exp_raw                                    float64
#  43  lbw_raw                                         float64
#  44  urban                                           float64
#  45  rural                                           float64
#  46  reservation                                     float64
#  47  city                                            int64
#  48  tot_pop                                         int64
#  49  pct_lths                                        float64
#  50  lfpr                                            float64
#  51  pct_bachmore                                    float64
#  52  County-Level Index                              float64
#  53  Requiring all 4 Subindices                      float64
#  54  Excluding Collective Efficacy                   float64
#  55  Family Unity                                    float64
#  56  Community Health                                float64
#  57  Institutional Health                            float64
#  58  Collective Efficacy                             float64
#  59  % births to unmarried women                     float64
#  60  % women currently married                       float64
#  61  % children with single parent                   float64
#  62  Non-religious non-profit organizations p 1,000  float64
#  63  Religious congregations p 1,000                 float64
#  64  Informal Civic Engagement Subindex              float64
#  65  Presidential election voting rate, 2012 & 2016  float64
#  66  Mail-back census response rate                  float64
#  67  Confidence in Institutions Subindex             float64
#  68  Violent Crimes p 100,000                        float64
#  69  ruca_cat                                        int64
# dtypes: float64(59), int64(11)
# memory usage: 4.4 GB

# %% [markdown]
# drop rows with incomplete data:

# %%
df_num_2=df_conus_num.dropna() # a fair number left
df_num_2
# Out:
#          NumberOfUniqueProviderNames  NumberOfUniqueHocoNums  \
# 0                                  3                       3
# 1                                  1                       1
# 2                                  2                       2
# 3                                  2                       2
# 4                                  1                       1
# ...                              ...                     ...
# 8254626                            1                       1
# 8254627                            1                       1
# 8254628                            3                       3
# 8254629                            1                       1
# 8254630                            1                       1
#
#          NumberOfUniqueTechCodes  NumFCCEntriesWith25/3Speed  \
# 0                              5                           3
# 1                              1                           1
# 2                              3                           1
# 3                              3                           1
# 4                              1                           1
# ...                          ...                         ...
# 8254626                        1                           1
# 8254627                        1                           0
# 8254628                        2                           3
# 8254629                        1                           0
# 8254630                        1                           0
#
#          NumFCCEntriesWith100/10Speed  AnyProviderWith25/3  \
# 0                                   3                    1
# 1                                   1                    1
# 2                                   1                    1
# 3                                   1                    1
# 4                                   1                    1
# ...                               ...                  ...
# 8254626                             0                    1
# 8254627                             0                    0
# 8254628                             0                    1
# 8254629                             0                    0
# 8254630                             0                    0
#
#          AnyProviderWith100/10  MeanMaxAdDown  MeanMaxAdUp  \
# 0                            1     592.800000    27.256000
# 1                            1     940.000000    35.000000
# 2                            1     317.333333    12.008000
# 3                            1     319.333333    12.008000
# 4                            1     940.000000    35.000000
# ...                        ...            ...          ...
# 8254626                      0      50.000000     5.000000
# 8254627                      0      10.000000     1.000000
# 8254628                      0      35.000000     8.333333
# 8254629                      0      10.000000     1.000000
# 8254630                      0      10.000000     1.000000
#
#          Tot_Population_ACS_14_18  ...  % women currently married  \
# 0                           636.0  ...                       65.2
# 1                           636.0  ...                       65.2
# 2                           636.0  ...                       65.2
# 3                           636.0  ...                       65.2
# 4                           636.0  ...                       65.2
# ...                           ...  ...                        ...
# 8254626                    1375.0  ...                       82.5
# 8254627                    1375.0  ...                       82.5
# 8254628                    1375.0  ...                       82.5
# 8254629                    1375.0  ...                       82.5
# 8254630                    1375.0  ...                       82.5
#
#          % children with single parent  \
# 0                                 22.4
# 1                                 22.4
# 2                                 22.4
# 3                                 22.4
# 4                                 22.4
# ...                                ...
# 8254626                           23.1
# 8254627                           23.1
# 8254628                           23.1
# 8254629                           23.1
# 8254630                           23.1
#
#          Non-religious non-profit organizations p 1,000  \
# 0                                                   2.2
# 1                                                   2.2
# 2                                                   2.2
# 3                                                   2.2
# 4                                                   2.2
# ...                                                 ...
# 8254626                                             8.0
# 8254627                                             8.0
# 8254628                                             8.0
# 8254629                                             8.0
# 8254630                                             8.0
#
#          Religious congregations p 1,000  Informal Civic Engagement Subindex  \
# 0                                    1.9                           -1.032341
# 1                                    1.9                           -1.032341
# 2                                    1.9                           -1.032341
# 3                                    1.9                           -1.032341
# 4                                    1.9                           -1.032341
# ...                                  ...                                 ...
# 8254626                              2.5                            0.414574
# 8254627                              2.5                            0.414574
# 8254628                              2.5                            0.414574
# 8254629                              2.5                            0.414574
# 8254630                              2.5                            0.414574
#
#          Presidential election voting rate, 2012 & 2016  \
# 0                                                  60.5
# 1                                                  60.5
# 2                                                  60.5
# 3                                                  60.5
# 4                                                  60.5
# ...                                                 ...
# 8254626                                            62.4
# 8254627                                            62.4
# 8254628                                            62.4
# 8254629                                            62.4
# 8254630                                            62.4
#
#          Mail-back census response rate  Confidence in Institutions Subindex  \
# 0                                  78.0                             0.208587
# 1                                  78.0                             0.208587
# 2                                  78.0                             0.208587
# 3                                  78.0                             0.208587
# 4                                  78.0                             0.208587
# ...                                 ...                                  ...
# 8254626                            65.0                             0.423832
# 8254627                            65.0                             0.423832
# 8254628                            65.0                             0.423832
# 8254629                            65.0                             0.423832
# 8254630                            65.0                             0.423832
#
#          Violent Crimes p 100,000  ruca_cat
# 0                           265.7         1
# 1                           265.7         1
# 2                           265.7         1
# 3                           265.7         1
# 4                           265.7         1
# ...                           ...       ...
# 8254626                     143.4         1
# 8254627                     143.4         1
# 8254628                     143.4         1
# 8254629                     143.4         1
# 8254630                     143.4         1
#
# [7990776 rows x 70 columns]

# %% [markdown]
# a list of all potential x variables:

# %%
all_x_li=['Tot_Population_ACS_14_18', 'pct_URBANIZED_AREA_POP_CEN_2010',
       'pct_URBAN_CLUSTER_POP_CEN_2010', 'pct_RURAL_POP_CEN_2010',
       'avg_Tot_Prns_in_HHD_ACS_14_18', 'pct_Vacant_Units_ACS_14_18',
       'pct_Hispanic_ACS_14_18', 'pct_NH_White_alone_ACS_14_18',
       'pct_NH_Blk_alone_ACS_14_18', 'pct_NH_AIAN_alone_ACS_14_18',
       'pct_NH_Asian_alone_ACS_14_18', 'pct_NH_NHOPI_alone_ACS_14_18',
       'pct_NH_SOR_alone_ACS_14_18', 'pct_Othr_Lang_ACS_14_18',
       'pct_ENG_VW_ACS_14_18', 'pct_Not_HS_Grad_ACS_14_18',
       'pct_College_ACS_14_18', 'avg_Agg_HH_INC_ACS_14_18',
       'pct_Prs_Blw_Pov_Lev_ACS_14_18', 'pct_PUB_ASST_INC_ACS_14_18',
       'pct_Diff_HU_1yr_Ago_ACS_14_18', 'pct_Recent_Built_HU_ACS_14_18',
       'avg_Agg_House_Value_ACS_14_18','Primary RUCA Code 2010','Secondary RUCA Code, 2010 (see errata)', 'Tract Population, 2010',
       'Land Area (square miles), 2010',
       'Population Density (per square mile), 2010','rank','index','mobility_raw','pct_belowpov_raw',\
                      'pct_deeppov_raw','life_exp_raw','lbw_raw','urban','rural','reservation',\
                      'tot_pop','pct_lths','lfpr','pct_bachmore','County-Level Index', \
                       'Requiring all 4 Subindices', 'Excluding Collective Efficacy', 'Family Unity', \
                       'Community Health', 'Institutional Health', 'Collective Efficacy', \
                       '% births to unmarried women', '% women currently married', '% children with single parent', \
                       'Non-religious non-profit organizations p 1,000', 'Religious congregations p 1,000', \
                       'Informal Civic Engagement Subindex', 'Presidential election voting rate, 2012 & 2016', \
                       'Mail-back census response rate', 'Confidence in Institutions Subindex', 'Violent Crimes p 100,000','ruca_cat']

# %% [markdown]
# Make x and y dataframe, and reset index so they match:

# %%
x=df_num_2[all_x_li]
y1=df_num_2['AnyProviderWith25/3']
y2=df_num_2['AnyProviderWith100/10']
x.reset_index(inplace=True,drop=True)
y1.reset_index(inplace=True,drop=True)
y2.reset_index(inplace=True,drop=True)
x.index,y1.index,y2.index
# Out:
# (RangeIndex(start=0, stop=7990776, step=1),
#  RangeIndex(start=0, stop=7990776, step=1),
#  RangeIndex(start=0, stop=7990776, step=1))

# %% [markdown]
# scale data to have mean = 0 and std = 1:

# %%
scaler = StandardScaler() 
x_scaled=scaler.fit_transform(x)
x_scaled = pd.DataFrame(x_scaled,columns=all_x_li)
x_scaled.head()
# Out:
#    Tot_Population_ACS_14_18  pct_URBANIZED_AREA_POP_CEN_2010  \
# 0                 -0.718103                         0.728437
# 1                 -0.718103                         0.728437
# 2                 -0.718103                         0.728437
# 3                 -0.718103                         0.728437
# 4                 -0.718103                         0.728437
#
#    pct_URBAN_CLUSTER_POP_CEN_2010  pct_RURAL_POP_CEN_2010  \
# 0                       -0.433958               -0.461839
# 1                       -0.433958               -0.461839
# 2                       -0.433958               -0.461839
# 3                       -0.433958               -0.461839
# 4                       -0.433958               -0.461839
#
#    avg_Tot_Prns_in_HHD_ACS_14_18  pct_Vacant_Units_ACS_14_18  \
# 0                      -0.897132                   -1.072048
# 1                      -0.897132                   -1.072048
# 2                      -0.897132                   -1.072048
# 3                      -0.897132                   -1.072048
# 4                      -0.897132                   -1.072048
#
#    pct_Hispanic_ACS_14_18  pct_NH_White_alone_ACS_14_18  \
# 0               -0.510827                       0.35896
# 1               -0.510827                       0.35896
# 2               -0.510827                       0.35896
# 3               -0.510827                       0.35896
# 4               -0.510827                       0.35896
#
#    pct_NH_Blk_alone_ACS_14_18  pct_NH_AIAN_alone_ACS_14_18  ...  \
# 0                   -0.061952                    -0.178966  ...
# 1                   -0.061952                    -0.178966  ...
# 2                   -0.061952                    -0.178966  ...
# 3                   -0.061952                    -0.178966  ...
# 4                   -0.061952                    -0.178966  ...
#
#    % women currently married  % children with single parent  \
# 0                    0.17741                      -0.982957
# 1                    0.17741                      -0.982957
# 2                    0.17741                      -0.982957
# 3                    0.17741                      -0.982957
# 4                    0.17741                      -0.982957
#
#    Non-religious non-profit organizations p 1,000  \
# 0                                       -1.032835
# 1                                       -1.032835
# 2                                       -1.032835
# 3                                       -1.032835
# 4                                       -1.032835
#
#    Religious congregations p 1,000  Informal Civic Engagement Subindex  \
# 0                         0.254016                            -0.89155
# 1                         0.254016                            -0.89155
# 2                         0.254016                            -0.89155
# 3                         0.254016                            -0.89155
# 4                         0.254016                            -0.89155
#
#    Presidential election voting rate, 2012 & 2016  \
# 0                                        0.167864
# 1                                        0.167864
# 2                                        0.167864
# 3                                        0.167864
# 4                                        0.167864
#
#    Mail-back census response rate  Confidence in Institutions Subindex  \
# 0                        0.553171                             0.377297
# 1                        0.553171                             0.377297
# 2                        0.553171                             0.377297
# 3                        0.553171                             0.377297
# 4                        0.553171                             0.377297
#
#    Violent Crimes p 100,000  ruca_cat
# 0                 -0.186864 -0.706168
# 1                 -0.186864 -0.706168
# 2                 -0.186864 -0.706168
# 3                 -0.186864 -0.706168
# 4                 -0.186864 -0.706168
#
# [5 rows x 60 columns]

# %% [markdown]
# #### 2. ANOVA on contiguous U.S
#
#
# define functions to compute ANOVA correlations for each x, first function outputs the best k features with highest correlations, second function outputs the best k features as well as the correlation scores and indices to sort them:

# %%
def anova_df(x,y,k):
    test=SelectKBest(score_func=f_classif,k=k)
    fit=test.fit(x,y)
    cols = test.get_support(indices=True)
    features_df =x.iloc[:,cols]
    return features_df

# %%
def anova_df_2(x,y,k):
    test=SelectKBest(score_func=f_classif,k=k)
    fit=test.fit(x,y)
    cols = test.get_support(indices=True)
    features_df =x.iloc[:,cols]
    return features_df,fit.scores_,np.argsort(fit.scores_)

# %% [markdown]
# run ANOVA on the scaled x dataframe, with y1 (AnyProviderWith25/3) first:

# %%
x_4_res=anova_df_2(x_scaled,y1,4) # get 4 best features
x_4=x_4_res[0]
x_4.head()
# Out:
#    pct_URBANIZED_AREA_POP_CEN_2010  pct_RURAL_POP_CEN_2010  \
# 0                         0.728437               -0.461839
# 1                         0.728437               -0.461839
# 2                         0.728437               -0.461839
# 3                         0.728437               -0.461839
# 4                         0.728437               -0.461839
#
#    Primary RUCA Code 2010  ruca_cat
# 0               -0.806122 -0.706168
# 1               -0.806122 -0.706168
# 2               -0.806122 -0.706168
# 3               -0.806122 -0.706168
# 4               -0.806122 -0.706168

# %%
x_4_scores=x_4_res[1] # ANOVA correlations
x_4_i=x_4_res[2] # index that would sort correlations in ascending order
x_4_scores,x_4_i
# Out:
# (array([7.18958834e+04, 9.03520410e+05, 3.79445202e+04, 1.30407217e+06,
#         1.04832009e+03, 3.41839954e+05, 3.30230974e+04, 3.93989943e+04,
#         3.85124397e+04, 2.31209416e+05, 1.26804754e+05, 2.80366801e+03,
#         1.19455040e+04, 2.91188559e+04, 1.21040718e+04, 3.84651363e+04,
#         2.39357361e+05, 1.19750577e+05, 1.99629585e+04, 4.60826146e+03,
#         6.31312356e+04, 5.67598556e+02, 4.57903328e+04, 7.27778624e+05,
#         7.26824225e+05, 7.87470112e+04, 5.20386010e+05, 2.97383642e+05,
#         2.99072968e+04, 4.46983052e+04, 1.23532312e+05, 1.29459695e+05,
#         6.92611259e+04, 2.27316503e+05, 4.71414909e+02, 5.97964070e+05,
#         5.97964070e+05, 2.42983453e+04, 1.44295219e+05, 9.07476456e+04,
#         3.31988574e+05, 4.55857047e+05, 4.31878826e+03, 4.31878826e+03,
#         3.87593061e+03, 6.71838984e+03, 1.86561860e+05, 1.29595956e+05,
#         7.26616925e+04, 2.83635934e+04, 8.04993615e+00, 4.22839399e+03,
#         2.67734165e+04, 6.22325314e+05, 8.98384782e+03, 8.24948697e+04,
#         3.08228237e+05, 9.72904243e+03, 7.26616920e+04, 7.66266937e+05]),
#  array([50, 34, 21,  4, 11, 44, 51, 42, 43, 19, 45, 54, 57, 12, 14, 18, 37,
#         52, 49, 13, 28,  6,  2, 15,  8,  7, 29, 22, 20, 32,  0, 58, 48, 25,
#         55, 39, 17, 30, 10, 31, 47, 38, 46, 33,  9, 16, 27, 56, 40,  5, 41,
#         26, 36, 35, 53, 24, 23, 59,  1,  3]))

# %%
scores_desc=np.flip(x_4_scores[x_4_i]) # sort scores in descending order
scores_desc
# Out:
# array([1.30407217e+06, 9.03520410e+05, 7.66266937e+05, 7.27778624e+05,
#        7.26824225e+05, 6.22325314e+05, 5.97964070e+05, 5.97964070e+05,
#        5.20386010e+05, 4.55857047e+05, 3.41839954e+05, 3.31988574e+05,
#        3.08228237e+05, 2.97383642e+05, 2.39357361e+05, 2.31209416e+05,
#        2.27316503e+05, 1.86561860e+05, 1.44295219e+05, 1.29595956e+05,
#        1.29459695e+05, 1.26804754e+05, 1.23532312e+05, 1.19750577e+05,
#        9.07476456e+04, 8.24948697e+04, 7.87470112e+04, 7.26616925e+04,
#        7.26616920e+04, 7.18958834e+04, 6.92611259e+04, 6.31312356e+04,
#        4.57903328e+04, 4.46983052e+04, 3.93989943e+04, 3.85124397e+04,
#        3.84651363e+04, 3.79445202e+04, 3.30230974e+04, 2.99072968e+04,
#        2.91188559e+04, 2.83635934e+04, 2.67734165e+04, 2.42983453e+04,
#        1.99629585e+04, 1.21040718e+04, 1.19455040e+04, 9.72904243e+03,
#        8.98384782e+03, 6.71838984e+03, 4.60826146e+03, 4.31878826e+03,
#        4.31878826e+03, 4.22839399e+03, 3.87593061e+03, 2.80366801e+03,
#        1.04832009e+03, 5.67598556e+02, 4.71414909e+02, 8.04993615e+00])

# %%
cols_desc=list(x_scaled.iloc[:3,x_4_i].columns) 
cols_desc.reverse()
cols_desc # corresponding columns for highest correlations to lowest
# Out:
# ['pct_RURAL_POP_CEN_2010',
#  'pct_URBANIZED_AREA_POP_CEN_2010',
#  'ruca_cat',
#  'Primary RUCA Code 2010',
#  'Secondary RUCA Code, 2010 (see errata)',
#  'Religious congregations p 1,000',
#  'urban',
#  'rural',
#  'Land Area (square miles), 2010',
#  'pct_bachmore',
#  'pct_Vacant_Units_ACS_14_18',
#  'lfpr',
#  'Mail-back census response rate',
#  'Population Density (per square mile), 2010',
#  'pct_College_ACS_14_18',
#  'pct_NH_AIAN_alone_ACS_14_18',
#  'life_exp_raw',
#  'Community Health',
#  'tot_pop',
#  'Institutional Health',
#  'pct_belowpov_raw',
#  'pct_NH_Asian_alone_ACS_14_18',
#  'mobility_raw',
#  'avg_Agg_HH_INC_ACS_14_18',
#  'pct_lths',
#  'Presidential election voting rate, 2012 & 2016',
#  'Tract Population, 2010',
#  'Collective Efficacy',
#  'Violent Crimes p 100,000',
#  'Tot_Population_ACS_14_18',
#  'pct_deeppov_raw',
#  'pct_Diff_HU_1yr_Ago_ACS_14_18',
#  'avg_Agg_House_Value_ACS_14_18',
#  'index',
#  'pct_NH_White_alone_ACS_14_18',
#  'pct_NH_Blk_alone_ACS_14_18',
#  'pct_Not_HS_Grad_ACS_14_18',
#  'pct_URBAN_CLUSTER_POP_CEN_2010',
#  'pct_Hispanic_ACS_14_18',
#  'rank',
#  'pct_Othr_Lang_ACS_14_18',
#  '% births to unmarried women',
#  'Non-religious non-profit organizations p 1,000',
#  'reservation',
#  'pct_Prs_Blw_Pov_Lev_ACS_14_18',
#  'pct_ENG_VW_ACS_14_18',
#  'pct_NH_SOR_alone_ACS_14_18',
#  'Confidence in Institutions Subindex',
#  'Informal Civic Engagement Subindex',
#  'Family Unity',
#  'pct_PUB_ASST_INC_ACS_14_18',
#  'Requiring all 4 Subindices',
#  'County-Level Index',
#  '% children with single parent',
#  'Excluding Collective Efficacy',
#  'pct_NH_NHOPI_alone_ACS_14_18',
#  'avg_Tot_Prns_in_HHD_ACS_14_18',
#  'pct_Recent_Built_HU_ACS_14_18',
#  'lbw_raw',
#  '% women currently married']

# %%
# pip install dataframe_image

# %% [markdown]
# Make a dataframe to show variables and their ANOVA correlations side by side, in descending order:

# %%
import dataframe_image as dfi
res_df=pd.DataFrame({'Variable':cols_desc,
        'ANOVA corr':scores_desc})
# dfi.export(res_df, '/Users/yapinghe/Desktop/broadband research/conus_anova_corr.png')
res_df.head()
# Out:
#                                  Variable    ANOVA corr
# 0                  pct_RURAL_POP_CEN_2010  1.304072e+06
# 1         pct_URBANIZED_AREA_POP_CEN_2010  9.035204e+05
# 2                                ruca_cat  7.662669e+05
# 3                  Primary RUCA Code 2010  7.277786e+05
# 4  Secondary RUCA Code, 2010 (see errata)  7.268242e+05

# %% [markdown]
# **contiguous U.S. result, y1:**

# %%
# res_df.to_csv('conus_anova_corr.csv')
res_df
# Out:
#                                           Variable    ANOVA corr
# 0                           pct_RURAL_POP_CEN_2010  1.304072e+06
# 1                  pct_URBANIZED_AREA_POP_CEN_2010  9.035204e+05
# 2                                         ruca_cat  7.662669e+05
# 3                           Primary RUCA Code 2010  7.277786e+05
# 4           Secondary RUCA Code, 2010 (see errata)  7.268242e+05
# 5                  Religious congregations p 1,000  6.223253e+05
# 6                                            urban  5.979641e+05
# 7                                            rural  5.979641e+05
# 8                   Land Area (square miles), 2010  5.203860e+05
# 9                                     pct_bachmore  4.558570e+05
# 10                      pct_Vacant_Units_ACS_14_18  3.418400e+05
# 11                                            lfpr  3.319886e+05
# 12                  Mail-back census response rate  3.082282e+05
# 13      Population Density (per square mile), 2010  2.973836e+05
# 14                           pct_College_ACS_14_18  2.393574e+05
# 15                     pct_NH_AIAN_alone_ACS_14_18  2.312094e+05
# 16                                    life_exp_raw  2.273165e+05
# 17                                Community Health  1.865619e+05
# 18                                         tot_pop  1.442952e+05
# 19                            Institutional Health  1.295960e+05
# 20                                pct_belowpov_raw  1.294597e+05
# 21                    pct_NH_Asian_alone_ACS_14_18  1.268048e+05
# 22                                    mobility_raw  1.235323e+05
# 23                        avg_Agg_HH_INC_ACS_14_18  1.197506e+05
# 24                                        pct_lths  9.074765e+04
# 25  Presidential election voting rate, 2012 & 2016  8.249487e+04
# 26                          Tract Population, 2010  7.874701e+04
# 27                             Collective Efficacy  7.266169e+04
# 28                        Violent Crimes p 100,000  7.266169e+04
# 29                        Tot_Population_ACS_14_18  7.189588e+04
# 30                                 pct_deeppov_raw  6.926113e+04
# 31                   pct_Diff_HU_1yr_Ago_ACS_14_18  6.313124e+04
# 32                   avg_Agg_House_Value_ACS_14_18  4.579033e+04
# 33                                           index  4.469831e+04
# 34                    pct_NH_White_alone_ACS_14_18  3.939899e+04
# 35                      pct_NH_Blk_alone_ACS_14_18  3.851244e+04
# 36                       pct_Not_HS_Grad_ACS_14_18  3.846514e+04
# 37                  pct_URBAN_CLUSTER_POP_CEN_2010  3.794452e+04
# 38                          pct_Hispanic_ACS_14_18  3.302310e+04
# 39                                            rank  2.990730e+04
# 40                         pct_Othr_Lang_ACS_14_18  2.911886e+04
# 41                     % births to unmarried women  2.836359e+04
# 42  Non-religious non-profit organizations p 1,000  2.677342e+04
# 43                                     reservation  2.429835e+04
# 44                   pct_Prs_Blw_Pov_Lev_ACS_14_18  1.996296e+04
# 45                            pct_ENG_VW_ACS_14_18  1.210407e+04
# 46                      pct_NH_SOR_alone_ACS_14_18  1.194550e+04
# 47             Confidence in Institutions Subindex  9.729042e+03
# 48              Informal Civic Engagement Subindex  8.983848e+03
# 49                                    Family Unity  6.718390e+03
# 50                      pct_PUB_ASST_INC_ACS_14_18  4.608261e+03
# 51                      Requiring all 4 Subindices  4.318788e+03
# 52                              County-Level Index  4.318788e+03
# 53                   % children with single parent  4.228394e+03
# 54                   Excluding Collective Efficacy  3.875931e+03
# 55                    pct_NH_NHOPI_alone_ACS_14_18  2.803668e+03
# 56                   avg_Tot_Prns_in_HHD_ACS_14_18  1.048320e+03
# 57                   pct_Recent_Built_HU_ACS_14_18  5.675986e+02
# 58                                         lbw_raw  4.714149e+02
# 59                       % women currently married  8.049936e+00

# %%
x_10_res=anova_df_2(x_scaled,y1,10)
x_10=x_10_res[0]
x_10.head() # match with above
# Out:
#   pct_URBANIZED_AREA_POP_CEN_2010 pct_RURAL_POP_CEN_2010  \
# 0                        0.728437              -0.461839
# 1                        0.728437              -0.461839
# 2                        0.728437              -0.461839
# 3                        0.728437              -0.461839
# 4                        0.728437              -0.461839
#
#   Primary RUCA Code 2010 Secondary RUCA Code, 2010 (see errata)  \
# 0              -0.806122                              -0.806349
# 1              -0.806122                              -0.806349
# 2              -0.806122                              -0.806349
# 3              -0.806122                              -0.806349
# 4              -0.806122                              -0.806349
#
#   Land Area (square miles), 2010     urban     rural pct_bachmore  \
# 0                      -0.326735  0.774281 -0.774281    -0.080054
# 1                      -0.326735  0.774281 -0.774281    -0.080054
# 2                      -0.326735  0.774281 -0.774281    -0.080054
# 3                      -0.326735  0.774281 -0.774281    -0.080054
# 4                      -0.326735  0.774281 -0.774281    -0.080054
#
#   Religious congregations p 1,000  ruca_cat
# 0                        0.254016 -0.706168
# 1                        0.254016 -0.706168
# 2                        0.254016 -0.706168
# 3                        0.254016 -0.706168
# 4                        0.254016 -0.706168

# %%
x_10_scores=x_10_res[1]
x_10_i=x_10_res[2]
x_10_scores,x_10_i
# Out:
# (array([7.18958834e+04, 9.03520410e+05, 3.79445202e+04, 1.30407217e+06,
#         1.04832009e+03, 3.41839954e+05, 3.30230974e+04, 3.93989943e+04,
#         3.85124397e+04, 2.31209416e+05, 1.26804754e+05, 2.80366801e+03,
#         1.19455040e+04, 2.91188559e+04, 1.21040718e+04, 3.84651363e+04,
#         2.39357361e+05, 1.19750577e+05, 1.99629585e+04, 4.60826146e+03,
#         6.31312356e+04, 5.67598556e+02, 4.57903328e+04, 7.27778624e+05,
#         7.26824225e+05, 7.87470112e+04, 5.20386010e+05, 2.97383642e+05,
#         2.99072968e+04, 4.46983052e+04, 1.23532312e+05, 1.29459695e+05,
#         6.92611259e+04, 2.27316503e+05, 4.71414909e+02, 5.97964070e+05,
#         5.97964070e+05, 2.42983453e+04, 1.44295219e+05, 9.07476456e+04,
#         3.31988574e+05, 4.55857047e+05, 4.31878826e+03, 4.31878826e+03,
#         3.87593061e+03, 6.71838984e+03, 1.86561860e+05, 1.29595956e+05,
#         7.26616925e+04, 2.83635934e+04, 8.04993615e+00, 4.22839399e+03,
#         2.67734165e+04, 6.22325314e+05, 8.98384782e+03, 8.24948697e+04,
#         3.08228237e+05, 9.72904243e+03, 7.26616920e+04, 7.66266937e+05]),
#  array([50, 34, 21,  4, 11, 44, 51, 42, 43, 19, 45, 54, 57, 12, 14, 18, 37,
#         52, 49, 13, 28,  6,  2, 15,  8,  7, 29, 22, 20, 32,  0, 58, 48, 25,
#         55, 39, 17, 30, 10, 31, 47, 38, 46, 33,  9, 16, 27, 56, 40,  5, 41,
#         26, 36, 35, 53, 24, 23, 59,  1,  3]))

# %% [markdown]
# ANOVA correlations are identical no matter what k (number of best features) we input, so no need to run it every time.
# Below is a way to order data so that each column to the right has a higher correlation:

# %%
# x_4_scores==x_10_scores, x_4_i==x_10_i # identical, no need to run anova for each k
x_scaled.iloc[:3,x_10_i[-10:]] # cols from low to high score
# Out:
#   pct_bachmore Land Area (square miles), 2010     rural     urban  \
# 0    -0.080054                      -0.326735 -0.774281  0.774281
# 1    -0.080054                      -0.326735 -0.774281  0.774281
# 2    -0.080054                      -0.326735 -0.774281  0.774281
#
#   Religious congregations p 1,000 Secondary RUCA Code, 2010 (see errata)  \
# 0                        0.254016                              -0.806349
# 1                        0.254016                              -0.806349
# 2                        0.254016                              -0.806349
#
#   Primary RUCA Code 2010  ruca_cat pct_URBANIZED_AREA_POP_CEN_2010  \
# 0              -0.806122 -0.706168                        0.728437
# 1              -0.806122 -0.706168                        0.728437
# 2              -0.806122 -0.706168                        0.728437
#
#   pct_RURAL_POP_CEN_2010
# 0              -0.461839
# 1              -0.461839
# 2              -0.461839

# %%
x_6=x_scaled.iloc[:,x_10_i[-6:]]
x_6.head()
# Out:
#   Religious congregations p 1,000 Secondary RUCA Code, 2010 (see errata)  \
# 0                        0.254016                              -0.806349
# 1                        0.254016                              -0.806349
# 2                        0.254016                              -0.806349
# 3                        0.254016                              -0.806349
# 4                        0.254016                              -0.806349
#
#   Primary RUCA Code 2010  ruca_cat pct_URBANIZED_AREA_POP_CEN_2010  \
# 0              -0.806122 -0.706168                        0.728437
# 1              -0.806122 -0.706168                        0.728437
# 2              -0.806122 -0.706168                        0.728437
# 3              -0.806122 -0.706168                        0.728437
# 4              -0.806122 -0.706168                        0.728437
#
#   pct_RURAL_POP_CEN_2010
# 0              -0.461839
# 1              -0.461839
# 2              -0.461839
# 3              -0.461839
# 4              -0.461839

# %%
x_8=x_scaled.iloc[:,x_10_i[-8:]]
x_8.head()
# Out:
#       rural     urban Religious congregations p 1,000  \
# 0 -0.774281  0.774281                        0.254016
# 1 -0.774281  0.774281                        0.254016
# 2 -0.774281  0.774281                        0.254016
# 3 -0.774281  0.774281                        0.254016
# 4 -0.774281  0.774281                        0.254016
#
#   Secondary RUCA Code, 2010 (see errata) Primary RUCA Code 2010  ruca_cat  \
# 0                              -0.806349              -0.806122 -0.706168
# 1                              -0.806349              -0.806122 -0.706168
# 2                              -0.806349              -0.806122 -0.706168
# 3                              -0.806349              -0.806122 -0.706168
# 4                              -0.806349              -0.806122 -0.706168
#
#   pct_URBANIZED_AREA_POP_CEN_2010 pct_RURAL_POP_CEN_2010
# 0                        0.728437              -0.461839
# 1                        0.728437              -0.461839
# 2                        0.728437              -0.461839
# 3                        0.728437              -0.461839
# 4                        0.728437              -0.461839

# %% [markdown]
# Repeat for y2 (AnyProviderWith100/10):

# %%
# y2
x_res_y2=anova_df_2(x_scaled,y2,4)
x_scores_y2=x_res_y2[1]
x_i_y2=x_res_y2[2]
x_scores_y2,x_i_y2
# Out:
# (array([9.08131493e+04, 1.78873317e+06, 4.72198279e+04, 2.55482889e+06,
#         2.25919087e+02, 3.91994199e+05, 2.14702854e+04, 1.00325187e+05,
#         1.11593340e+05, 1.60444361e+05, 2.18502024e+05, 2.96347296e+03,
#         2.09144938e+04, 5.24788609e+04, 1.76943230e+04, 4.43511353e+04,
#         3.83173983e+05, 1.38021839e+05, 5.01975608e+03, 1.08653151e+04,
#         1.05533087e+05, 6.41775208e+01, 5.16274761e+04, 1.19353533e+06,
#         1.19208167e+06, 9.82729965e+04, 5.69334970e+05, 5.74818641e+05,
#         4.48987699e+03, 8.70278307e+03, 3.30830350e+05, 1.08660343e+05,
#         4.54896131e+04, 2.25526195e+05, 2.95090110e+04, 8.30190240e+05,
#         8.30190240e+05, 1.57302043e+04, 2.81002402e+05, 1.19133522e+05,
#         3.45292643e+05, 7.26739964e+05, 5.36474647e+04, 5.36474647e+04,
#         7.89174880e+03, 6.30650632e+03, 3.53743683e+05, 9.61148840e+04,
#         1.59808411e+05, 7.56247732e+03, 4.10007887e+04, 5.82171455e+03,
#         6.76928106e+04, 8.68920411e+05, 4.86124482e+04, 1.05312618e+05,
#         3.32450160e+05, 1.24984845e+03, 1.59808405e+05, 1.37058132e+06]),
#  array([21,  4, 57, 11, 28, 18, 51, 45, 49, 44, 29, 19, 37, 14, 12,  6, 34,
#         50, 15, 32,  2, 54, 22, 13, 43, 42, 52,  0, 47, 25,  7, 55, 20, 31,
#          8, 39, 17, 58, 48,  9, 10, 33, 38, 30, 56, 40, 46, 16,  5, 26, 27,
#         41, 36, 35, 53, 24, 23, 59,  1,  3]))

# %% [markdown]
# **contiguous U.S result, y2:**

# %%
scores_desc_y2=np.flip(x_scores_y2[x_i_y2])
cols_desc_y2=list(x_scaled.iloc[:3,x_i_y2].columns)
cols_desc_y2.reverse()
res_df_y2=pd.DataFrame({'Variable':cols_desc_y2,
        'ANOVA corr':scores_desc_y2})
# dfi.export(res_df_y2, '/Users/yapinghe/Desktop/broadband research/conus_anova_corr_y2.png')
res_df_y2
# Out:
#                                           Variable    ANOVA corr
# 0                           pct_RURAL_POP_CEN_2010  2.554829e+06
# 1                  pct_URBANIZED_AREA_POP_CEN_2010  1.788733e+06
# 2                                         ruca_cat  1.370581e+06
# 3                           Primary RUCA Code 2010  1.193535e+06
# 4           Secondary RUCA Code, 2010 (see errata)  1.192082e+06
# 5                  Religious congregations p 1,000  8.689204e+05
# 6                                            urban  8.301902e+05
# 7                                            rural  8.301902e+05
# 8                                     pct_bachmore  7.267400e+05
# 9       Population Density (per square mile), 2010  5.748186e+05
# 10                  Land Area (square miles), 2010  5.693350e+05
# 11                      pct_Vacant_Units_ACS_14_18  3.919942e+05
# 12                           pct_College_ACS_14_18  3.831740e+05
# 13                                Community Health  3.537437e+05
# 14                                            lfpr  3.452926e+05
# 15                  Mail-back census response rate  3.324502e+05
# 16                                    mobility_raw  3.308303e+05
# 17                                         tot_pop  2.810024e+05
# 18                                    life_exp_raw  2.255262e+05
# 19                    pct_NH_Asian_alone_ACS_14_18  2.185020e+05
# 20                     pct_NH_AIAN_alone_ACS_14_18  1.604444e+05
# 21                             Collective Efficacy  1.598084e+05
# 22                        Violent Crimes p 100,000  1.598084e+05
# 23                        avg_Agg_HH_INC_ACS_14_18  1.380218e+05
# 24                                        pct_lths  1.191335e+05
# 25                      pct_NH_Blk_alone_ACS_14_18  1.115933e+05
# 26                                pct_belowpov_raw  1.086603e+05
# 27                   pct_Diff_HU_1yr_Ago_ACS_14_18  1.055331e+05
# 28  Presidential election voting rate, 2012 & 2016  1.053126e+05
# 29                    pct_NH_White_alone_ACS_14_18  1.003252e+05
# 30                          Tract Population, 2010  9.827300e+04
# 31                            Institutional Health  9.611488e+04
# 32                        Tot_Population_ACS_14_18  9.081315e+04
# 33  Non-religious non-profit organizations p 1,000  6.769281e+04
# 34                              County-Level Index  5.364746e+04
# 35                      Requiring all 4 Subindices  5.364746e+04
# 36                         pct_Othr_Lang_ACS_14_18  5.247886e+04
# 37                   avg_Agg_House_Value_ACS_14_18  5.162748e+04
# 38              Informal Civic Engagement Subindex  4.861245e+04
# 39                  pct_URBAN_CLUSTER_POP_CEN_2010  4.721983e+04
# 40                                 pct_deeppov_raw  4.548961e+04
# 41                       pct_Not_HS_Grad_ACS_14_18  4.435114e+04
# 42                       % women currently married  4.100079e+04
# 43                                         lbw_raw  2.950901e+04
# 44                          pct_Hispanic_ACS_14_18  2.147029e+04
# 45                      pct_NH_SOR_alone_ACS_14_18  2.091449e+04
# 46                            pct_ENG_VW_ACS_14_18  1.769432e+04
# 47                                     reservation  1.573020e+04
# 48                      pct_PUB_ASST_INC_ACS_14_18  1.086532e+04
# 49                                           index  8.702783e+03
# 50                   Excluding Collective Efficacy  7.891749e+03
# 51                     % births to unmarried women  7.562477e+03
# 52                                    Family Unity  6.306506e+03
# 53                   % children with single parent  5.821715e+03
# 54                   pct_Prs_Blw_Pov_Lev_ACS_14_18  5.019756e+03
# 55                                            rank  4.489877e+03
# 56                    pct_NH_NHOPI_alone_ACS_14_18  2.963473e+03
# 57             Confidence in Institutions Subindex  1.249848e+03
# 58                   avg_Tot_Prns_in_HHD_ACS_14_18  2.259191e+02
# 59                   pct_Recent_Built_HU_ACS_14_18  6.417752e+01

# %%
# res_df_y2.to_csv('conus_anova_corr_y2.csv')

# %% [markdown]
# #### 3. ANOVA on RUCA categories
# Now we do the same analysis for each RUCA category (core, suburb, exurb, rural) and see if the results are different:
# I used 1 to indicate core, 2 for suburb, 3 for exurb, 4 for rural

# %%
# first by ruca category
rc1=df_num_2[df_num_2['ruca_cat']==1] #core
rc2=df_num_2[df_num_2['ruca_cat']==2] #suburb
rc3=df_num_2[df_num_2['ruca_cat']==3] #exurb
rc4=df_num_2[df_num_2['ruca_cat']==4] #rural
len(rc1),len(rc2),len(rc3),len(rc4)
# Out:
# (4587762, 2037480, 341765, 1023769)

# %% [markdown]
# create x and y dataframes for each category and reset index:

# %%
x_rc1=rc1[all_x_li]
x_rc2=rc2[all_x_li]
x_rc3=rc3[all_x_li]
x_rc4=rc4[all_x_li]
y1_rc1=rc1['AnyProviderWith25/3']
y2_rc1=rc1['AnyProviderWith100/10']
y1_rc2=rc2['AnyProviderWith25/3']
y2_rc2=rc2['AnyProviderWith100/10']
y1_rc3=rc3['AnyProviderWith25/3']
y2_rc3=rc3['AnyProviderWith100/10']
y1_rc4=rc4['AnyProviderWith25/3']
y2_rc4=rc4['AnyProviderWith100/10']
y1_rc1.reset_index(inplace=True,drop=True)
y2_rc1.reset_index(inplace=True,drop=True)
y1_rc2.reset_index(inplace=True,drop=True)
y2_rc2.reset_index(inplace=True,drop=True)
y1_rc3.reset_index(inplace=True,drop=True)
y2_rc3.reset_index(inplace=True,drop=True)
y1_rc4.reset_index(inplace=True,drop=True)
y2_rc4.reset_index(inplace=True,drop=True)

# %% [markdown]
# scale all the x dataframes for each category:

# %%
scaler = StandardScaler() 
x_rc1_scaled=scaler.fit_transform(x_rc1)
x_rc2_scaled=scaler.fit_transform(x_rc2)
x_rc3_scaled=scaler.fit_transform(x_rc3)
x_rc4_scaled=scaler.fit_transform(x_rc4)
x_rc1_scaled = pd.DataFrame(x_rc1_scaled,columns=all_x_li)
x_rc2_scaled = pd.DataFrame(x_rc2_scaled,columns=all_x_li)
x_rc3_scaled = pd.DataFrame(x_rc3_scaled,columns=all_x_li)
x_rc4_scaled = pd.DataFrame(x_rc4_scaled,columns=all_x_li)
x_rc1_scaled.index==y1_rc1.index, x_rc2_scaled.index==y1_rc2.index, x_rc3_scaled.index==y1_rc3.index, x_rc4_scaled.index==y1_rc4.index
# Out:
# (array([ True,  True,  True, ...,  True,  True,  True]),
#  array([ True,  True,  True, ...,  True,  True,  True]),
#  array([ True,  True,  True, ...,  True,  True,  True]),
#  array([ True,  True,  True, ...,  True,  True,  True]))

# %% [markdown]
# Run ANOVA correlations on core area:

# %%
#rc1
x_rc1_res=anova_df_2(x_rc1_scaled,y1_rc1,4) # best 4 features
x_4_rc1=x_rc1_res[0]
x_rc1_scores=x_rc1_res[1]
x_rc1_i=x_rc1_res[2]
x_4_rc1.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [59] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    pct_URBANIZED_AREA_POP_CEN_2010  pct_RURAL_POP_CEN_2010  \
# 0                         0.139383                0.455694
# 1                         0.139383                0.455694
# 2                         0.139383                0.455694
# 3                         0.139383                0.455694
# 4                         0.139383                0.455694
#
#    Secondary RUCA Code, 2010 (see errata)  Land Area (square miles), 2010
# 0                               -0.540137                       -0.146724
# 1                               -0.540137                       -0.146724
# 2                               -0.540137                       -0.146724
# 3                               -0.540137                       -0.146724
# 4                               -0.540137                       -0.146724

# %%
x_rc1_scores,x_rc1_i # correlation scores, and index for sorting in ascending order
# nan corresponds to ruca_cat, which is RUCA category, 
# which is the same in x of every category so it gives nan as score
# Out:
# (array([2.93655933e+03, 2.34983597e+05, 2.39491810e+04, 3.64106641e+05,
#         7.58569344e+02, 5.48335892e+04, 1.85414052e+01, 4.98944866e+03,
#         4.41968644e+03, 3.25559513e+04, 2.30219347e+04, 4.06611839e+02,
#         1.79216693e+03, 4.66847811e+03, 1.65143891e+03, 9.23756232e+03,
#         3.60260249e+04, 1.79703904e+04, 3.52222105e+03, 1.07090330e+03,
#         4.38066839e+02, 1.49099905e+03, 1.05019286e+04, 2.17325683e+05,
#         2.17362850e+05, 3.53331454e+01, 2.26648598e+05, 7.36512278e+04,
#         9.05859886e+03, 1.23131515e+04, 3.56757164e+04, 2.99259762e+04,
#         1.96121666e+04, 4.86152257e+04, 6.71276247e+02, 1.76838353e+05,
#         1.76838353e+05, 1.06202937e+04, 2.52929220e+04, 3.10432365e+04,
#         6.57624086e+04, 9.66087659e+04, 1.08900245e+02, 1.08900245e+02,
#         5.19013615e+03, 2.10516289e+03, 4.05752704e+04, 4.54796026e+04,
#         6.78907608e+03, 6.89137258e+03, 6.65758394e+01, 3.03388203e+03,
#         4.15888134e+03, 1.69439362e+05, 2.97343475e+03, 3.79789275e+04,
#         7.98886500e+04, 6.23393375e+03, 6.78907564e+03,            nan]),
#  array([ 6, 25, 50, 42, 43, 11, 20, 34,  4, 19, 21, 14, 12, 45,  0, 54, 51,
#         18, 52,  8, 13,  7, 44, 57, 58, 48, 49, 28, 15, 22, 37, 29, 17, 32,
#         10,  2, 38, 31, 39,  9, 30, 16, 55, 46, 47, 33,  5, 40, 27, 56, 41,
#         53, 36, 35, 23, 24, 26,  1,  3, 59]))

# %%
x_6_rc1=x_rc1_scaled.iloc[:,x_rc1_i[-7:-1]] # remove nan index (from ruca cat)
x_6_rc1.head() # best 6 features, sorted from lower scores (left) to higher (right)
# Out:
#       urban  Primary RUCA Code 2010  Secondary RUCA Code, 2010 (see errata)  \
# 0  0.504483               -0.538984                               -0.540137
# 1  0.504483               -0.538984                               -0.540137
# 2  0.504483               -0.538984                               -0.540137
# 3  0.504483               -0.538984                               -0.540137
# 4  0.504483               -0.538984                               -0.540137
#
#    Land Area (square miles), 2010  pct_URBANIZED_AREA_POP_CEN_2010  \
# 0                       -0.146724                         0.139383
# 1                       -0.146724                         0.139383
# 2                       -0.146724                         0.139383
# 3                       -0.146724                         0.139383
# 4                       -0.146724                         0.139383
#
#    pct_RURAL_POP_CEN_2010
# 0                0.455694
# 1                0.455694
# 2                0.455694
# 3                0.455694
# 4                0.455694

# %%
x_8_rc1=x_rc1_scaled.iloc[:,x_rc1_i[-9:-1]]
x_8_rc1.head() # best 8 features, sorted from lower scores (left) to higher (right)
# Out:
#    Religious congregations p 1,000     rural     urban  \
# 0                         0.935834 -0.504483  0.504483
# 1                         0.935834 -0.504483  0.504483
# 2                         0.935834 -0.504483  0.504483
# 3                         0.935834 -0.504483  0.504483
# 4                         0.935834 -0.504483  0.504483
#
#    Primary RUCA Code 2010  Secondary RUCA Code, 2010 (see errata)  \
# 0               -0.538984                               -0.540137
# 1               -0.538984                               -0.540137
# 2               -0.538984                               -0.540137
# 3               -0.538984                               -0.540137
# 4               -0.538984                               -0.540137
#
#    Land Area (square miles), 2010  pct_URBANIZED_AREA_POP_CEN_2010  \
# 0                       -0.146724                         0.139383
# 1                       -0.146724                         0.139383
# 2                       -0.146724                         0.139383
# 3                       -0.146724                         0.139383
# 4                       -0.146724                         0.139383
#
#    pct_RURAL_POP_CEN_2010
# 0                0.455694
# 1                0.455694
# 2                0.455694
# 3                0.455694
# 4                0.455694

# %%
x_10_rc1=x_rc1_scaled.iloc[:,x_rc1_i[-11:-1]]
x_10_rc1.head() # best 10 features, sorted from lower scores (left) to higher (right)
# Out:
#    Mail-back census response rate  pct_bachmore  \
# 0                        0.529322     -0.394264
# 1                        0.529322     -0.394264
# 2                        0.529322     -0.394264
# 3                        0.529322     -0.394264
# 4                        0.529322     -0.394264
#
#    Religious congregations p 1,000     rural     urban  \
# 0                         0.935834 -0.504483  0.504483
# 1                         0.935834 -0.504483  0.504483
# 2                         0.935834 -0.504483  0.504483
# 3                         0.935834 -0.504483  0.504483
# 4                         0.935834 -0.504483  0.504483
#
#    Primary RUCA Code 2010  Secondary RUCA Code, 2010 (see errata)  \
# 0               -0.538984                               -0.540137
# 1               -0.538984                               -0.540137
# 2               -0.538984                               -0.540137
# 3               -0.538984                               -0.540137
# 4               -0.538984                               -0.540137
#
#    Land Area (square miles), 2010  pct_URBANIZED_AREA_POP_CEN_2010  \
# 0                       -0.146724                         0.139383
# 1                       -0.146724                         0.139383
# 2                       -0.146724                         0.139383
# 3                       -0.146724                         0.139383
# 4                       -0.146724                         0.139383
#
#    pct_RURAL_POP_CEN_2010
# 0                0.455694
# 1                0.455694
# 2                0.455694
# 3                0.455694
# 4                0.455694

# %% [markdown]
# construct dataframe with variable names and their correlations side by side:
# **core result:**

# %%
scores_desc_rc1=np.flip(x_rc1_scores[x_rc1_i])
cols_desc_rc1=list(x_rc1_scaled.iloc[:3,x_rc1_i].columns) #remove last index?
cols_desc_rc1.reverse()
res_df_rc1=pd.DataFrame({'Variable':cols_desc_rc1,
        'ANOVA corr':scores_desc_rc1}).iloc[1:,:]
# dfi.export(res_df_rc1, '/Users/yapinghe/Desktop/broadband research/ruca_core_anova_corr.png')
# res_df_rc1.to_csv('ruca_core_anova_corr.csv')
res_df_rc1
# Out:
#                                           Variable     ANOVA corr
# 1                           pct_RURAL_POP_CEN_2010  364106.641416
# 2                  pct_URBANIZED_AREA_POP_CEN_2010  234983.596836
# 3                   Land Area (square miles), 2010  226648.598132
# 4           Secondary RUCA Code, 2010 (see errata)  217362.850407
# 5                           Primary RUCA Code 2010  217325.683398
# 6                                            urban  176838.352925
# 7                                            rural  176838.352925
# 8                  Religious congregations p 1,000  169439.361888
# 9                                     pct_bachmore   96608.765903
# 10                  Mail-back census response rate   79888.649973
# 11      Population Density (per square mile), 2010   73651.227798
# 12                                            lfpr   65762.408642
# 13                      pct_Vacant_Units_ACS_14_18   54833.589172
# 14                                    life_exp_raw   48615.225686
# 15                            Institutional Health   45479.602643
# 16                                Community Health   40575.270397
# 17  Presidential election voting rate, 2012 & 2016   37978.927463
# 18                           pct_College_ACS_14_18   36026.024873
# 19                                    mobility_raw   35675.716394
# 20                     pct_NH_AIAN_alone_ACS_14_18   32555.951301
# 21                                        pct_lths   31043.236471
# 22                                pct_belowpov_raw   29925.976236
# 23                                         tot_pop   25292.922024
# 24                  pct_URBAN_CLUSTER_POP_CEN_2010   23949.180999
# 25                    pct_NH_Asian_alone_ACS_14_18   23021.934695
# 26                                 pct_deeppov_raw   19612.166554
# 27                        avg_Agg_HH_INC_ACS_14_18   17970.390429
# 28                                           index   12313.151544
# 29                                     reservation   10620.293677
# 30                   avg_Agg_House_Value_ACS_14_18   10501.928559
# 31                       pct_Not_HS_Grad_ACS_14_18    9237.562315
# 32                                            rank    9058.598859
# 33                     % births to unmarried women    6891.372584
# 34                             Collective Efficacy    6789.076079
# 35                        Violent Crimes p 100,000    6789.075640
# 36             Confidence in Institutions Subindex    6233.933754
# 37                   Excluding Collective Efficacy    5190.136150
# 38                    pct_NH_White_alone_ACS_14_18    4989.448662
# 39                         pct_Othr_Lang_ACS_14_18    4668.478107
# 40                      pct_NH_Blk_alone_ACS_14_18    4419.686440
# 41  Non-religious non-profit organizations p 1,000    4158.881335
# 42                   pct_Prs_Blw_Pov_Lev_ACS_14_18    3522.221048
# 43                   % children with single parent    3033.882035
# 44              Informal Civic Engagement Subindex    2973.434749
# 45                        Tot_Population_ACS_14_18    2936.559329
# 46                                    Family Unity    2105.162888
# 47                      pct_NH_SOR_alone_ACS_14_18    1792.166931
# 48                            pct_ENG_VW_ACS_14_18    1651.438908
# 49                   pct_Recent_Built_HU_ACS_14_18    1490.999049
# 50                      pct_PUB_ASST_INC_ACS_14_18    1070.903296
# 51                   avg_Tot_Prns_in_HHD_ACS_14_18     758.569344
# 52                                         lbw_raw     671.276247
# 53                   pct_Diff_HU_1yr_Ago_ACS_14_18     438.066839
# 54                    pct_NH_NHOPI_alone_ACS_14_18     406.611839
# 55                      Requiring all 4 Subindices     108.900245
# 56                              County-Level Index     108.900245
# 57                       % women currently married      66.575839
# 58                          Tract Population, 2010      35.333145
# 59                          pct_Hispanic_ACS_14_18      18.541405

# %% [markdown]
# repeat for suburb category:

# %%
# rc2
x_rc2_res=anova_df_2(x_rc2_scaled,y1_rc2,4)
x_4_rc2=x_rc2_res[0]
x_rc2_scores=x_rc2_res[1]
x_rc2_i=x_rc2_res[2]
x_4_rc2.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [59] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    pct_RURAL_POP_CEN_2010  Land Area (square miles), 2010  \
# 0               -0.216133                       -0.349854
# 1               -0.216133                       -0.349854
# 2               -0.216133                       -0.349854
# 3               -0.216133                       -0.349854
# 4               -0.216133                       -0.349854
#
#    Religious congregations p 1,000  Mail-back census response rate
# 0                         0.042894                        0.518921
# 1                         0.042894                        0.518921
# 2                         0.042894                        0.518921
# 3                         0.042894                        0.518921
# 4                         0.042894                        0.518921

# %%
# x_rc2_scores,x_rc2_i # need to remove last index (from ruca cat)

# %%
x_10_rc2=x_rc2_scaled.iloc[:,x_rc2_i[-11:-1]] # remove nan index
x_10_rc2.head()
# Out:
#    Secondary RUCA Code, 2010 (see errata)  Primary RUCA Code 2010  \
# 0                                -0.71695                -0.71643
# 1                                -0.71695                -0.71643
# 2                                -0.71695                -0.71643
# 3                                -0.71695                -0.71643
# 4                                -0.71695                -0.71643
#
#    pct_bachmore      lfpr  Institutional Health  pct_NH_AIAN_alone_ACS_14_18  \
# 0      0.251263  0.058532              0.464704                    -0.201115
# 1      0.251263  0.058532              0.464704                    -0.201115
# 2      0.251263  0.058532              0.464704                    -0.201115
# 3      0.251263  0.058532              0.464704                    -0.201115
# 4      0.251263  0.058532              0.464704                    -0.201115
#
#    Religious congregations p 1,000  Mail-back census response rate  \
# 0                         0.042894                        0.518921
# 1                         0.042894                        0.518921
# 2                         0.042894                        0.518921
# 3                         0.042894                        0.518921
# 4                         0.042894                        0.518921
#
#    Land Area (square miles), 2010  pct_RURAL_POP_CEN_2010
# 0                       -0.349854               -0.216133
# 1                       -0.349854               -0.216133
# 2                       -0.349854               -0.216133
# 3                       -0.349854               -0.216133
# 4                       -0.349854               -0.216133

# %%
# can get x_6, x_8 easily

# %% [markdown]
# **suburb result:**

# %%
scores_desc_rc2=np.flip(x_rc2_scores[x_rc2_i])
cols_desc_rc2=list(x_rc2_scaled.iloc[:3,x_rc2_i].columns) #remove last index?
cols_desc_rc2.reverse()
res_df_rc2=pd.DataFrame({'Variable':cols_desc_rc2,
        'ANOVA corr':scores_desc_rc2}).iloc[1:,:]
# dfi.export(res_df_rc2, '/Users/yapinghe/Desktop/broadband research/ruca_suburb_anova_corr.png')
# res_df_rc2.to_csv('ruca_suburb_anova_corr.csv')
res_df_rc2
# Out:
#                                           Variable    ANOVA corr
# 1                           pct_RURAL_POP_CEN_2010  68165.024077
# 2                   Land Area (square miles), 2010  66929.685478
# 3                   Mail-back census response rate  60773.987977
# 4                  Religious congregations p 1,000  57228.353077
# 5                      pct_NH_AIAN_alone_ACS_14_18  55830.133463
# 6                             Institutional Health  51311.259277
# 7                                             lfpr  44342.764646
# 8                                     pct_bachmore  43257.119219
# 9                           Primary RUCA Code 2010  41846.944409
# 10          Secondary RUCA Code, 2010 (see errata)  41813.140155
# 11                                           rural  41213.300170
# 12                                           urban  41213.300170
# 13                  pct_URBAN_CLUSTER_POP_CEN_2010  40964.730015
# 14                      pct_Vacant_Units_ACS_14_18  36888.857435
# 15                                pct_belowpov_raw  34439.825252
# 16                                    life_exp_raw  32469.272936
# 17      Population Density (per square mile), 2010  29076.707473
# 18                        avg_Agg_HH_INC_ACS_14_18  27873.095303
# 19                           pct_College_ACS_14_18  27351.558225
# 20  Presidential election voting rate, 2012 & 2016  26592.099796
# 21                   Excluding Collective Efficacy  26368.628939
# 22                                           index  24733.757605
# 23                                        pct_lths  23926.199727
# 24                        Tot_Population_ACS_14_18  22963.832285
# 25                                 pct_deeppov_raw  22055.135513
# 26                                            rank  21872.627761
# 27                    pct_NH_White_alone_ACS_14_18  21457.093990
# 28                 pct_URBANIZED_AREA_POP_CEN_2010  21379.903786
# 29                              County-Level Index  20611.089256
# 30                      Requiring all 4 Subindices  20611.089256
# 31                                    Family Unity  20049.377987
# 32                       pct_Not_HS_Grad_ACS_14_18  17778.507774
# 33                          Tract Population, 2010  17174.836678
# 34             Confidence in Institutions Subindex  17138.506005
# 35                   pct_Prs_Blw_Pov_Lev_ACS_14_18  16812.442617
# 36                       % women currently married  16249.977405
# 37                     % births to unmarried women  14753.806585
# 38                   % children with single parent  14606.683372
# 39                                         lbw_raw  12696.674551
# 40                   avg_Agg_House_Value_ACS_14_18  12165.307528
# 41                                     reservation  11292.129603
# 42                         pct_Othr_Lang_ACS_14_18  10848.541402
# 43                    pct_NH_Asian_alone_ACS_14_18   9216.558693
# 44                            pct_ENG_VW_ACS_14_18   7396.247860
# 45                                         tot_pop   4961.037851
# 46                                Community Health   4715.114703
# 47                   pct_Diff_HU_1yr_Ago_ACS_14_18   3243.671518
# 48                             Collective Efficacy   2836.763760
# 49                        Violent Crimes p 100,000   2836.763644
# 50              Informal Civic Engagement Subindex   2393.226070
# 51                      pct_NH_Blk_alone_ACS_14_18   1552.746261
# 52                   pct_Recent_Built_HU_ACS_14_18    877.260464
# 53                   avg_Tot_Prns_in_HHD_ACS_14_18    713.031207
# 54                      pct_NH_SOR_alone_ACS_14_18    621.646600
# 55                                    mobility_raw    499.124018
# 56                          pct_Hispanic_ACS_14_18    140.425322
# 57                      pct_PUB_ASST_INC_ACS_14_18    104.776654
# 58                    pct_NH_NHOPI_alone_ACS_14_18     48.394922
# 59  Non-religious non-profit organizations p 1,000      5.991452

# %% [markdown]
# repeat for exurb category:

# %%
# rc3
x_rc3_res=anova_df_2(x_rc3_scaled,y1_rc3,4)
x_4_rc3=x_rc3_res[0]
x_rc3_scores=x_rc3_res[1]
x_rc3_i=x_rc3_res[2]
x_4_rc3.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [59] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    pct_NH_AIAN_alone_ACS_14_18  pct_belowpov_raw  pct_deeppov_raw      lfpr
# 0                    -0.205765         -0.737204        -0.624973  0.064204
# 1                    -0.205765         -0.737204        -0.624973  0.064204
# 2                    -0.205765         -0.737204        -0.624973  0.064204
# 3                    -0.205765         -0.737204        -0.624973  0.064204
# 4                    -0.205765         -0.737204        -0.624973  0.064204

# %%
x_rc3_scores,x_rc3_i
# Out:
# (array([2.83921678e+03, 4.99754520e+02, 5.03430919e+03, 5.50422160e+03,
#         4.62241763e+02, 3.15325174e+03, 1.36110848e+03, 5.33445435e+03,
#         2.05372156e+03, 1.22187891e+04, 5.46269460e+02, 1.73630398e+01,
#         3.97272166e+02, 3.17448657e+03, 2.73353829e+03, 5.22914994e+03,
#         5.79651763e+03, 8.69824925e+03, 7.13725687e+03, 1.65474738e+02,
#         1.11551255e+03, 1.88838162e+00, 3.41156813e+03, 4.25577182e+02,
#         4.25577182e+02, 3.96817075e+03, 4.55049680e+03, 3.70070156e+03,
#         7.81805483e+03, 8.99268488e+03, 3.12503876e+02, 1.13123271e+04,
#         1.24390722e+04, 3.47749553e+03, 5.41432685e+03, 1.90425164e+03,
#         1.90425164e+03, 2.15228153e+03, 2.30494485e+02, 3.26057502e+03,
#         9.16645352e+03, 4.47468458e+03, 2.88442345e+03, 2.88442345e+03,
#         3.88227630e+03, 3.93462445e+03, 1.50014212e+01, 4.33598342e+03,
#         1.78291487e+02, 9.04301852e+02, 5.65775861e+03, 3.09902131e+03,
#         2.69178114e+03, 8.45608951e+03, 4.03812236e+02, 1.56944938e+03,
#         3.72895052e+03, 2.24093353e+03, 1.78291464e+02,            nan]),
#  array([21, 46, 11, 19, 58, 48, 38, 30, 12, 54, 23, 24,  4,  1, 10, 49, 20,
#          6, 55, 36, 35,  8, 37, 57, 52, 14,  0, 43, 42, 51,  5, 13, 39, 22,
#         33, 27, 56, 44, 45, 25, 47, 41, 26,  2, 15,  7, 34,  3, 50, 16, 18,
#         28, 53, 17, 29, 40, 31,  9, 32, 59]))

# %%
x_10_rc3=x_rc3_scaled.iloc[:,x_rc3_i[-11:-1]] # remove nan index
x_10_rc3.head()
# Out:
#    pct_College_ACS_14_18  pct_Prs_Blw_Pov_Lev_ACS_14_18      rank  \
# 0               0.413788                      -0.119464  0.351685
# 1               0.413788                      -0.119464  0.351685
# 2               0.413788                      -0.119464  0.351685
# 3               0.413788                      -0.119464  0.351685
# 4               0.413788                      -0.119464  0.351685
#
#    Religious congregations p 1,000  avg_Agg_HH_INC_ACS_14_18     index  \
# 0                        -0.668572                  -1.45849  0.346571
# 1                        -0.668572                  -1.45849  0.346571
# 2                        -0.668572                  -1.45849  0.346571
# 3                        -0.668572                  -1.45849  0.346571
# 4                        -0.668572                  -1.45849  0.346571
#
#        lfpr  pct_belowpov_raw  pct_NH_AIAN_alone_ACS_14_18  pct_deeppov_raw
# 0  0.064204         -0.737204                    -0.205765        -0.624973
# 1  0.064204         -0.737204                    -0.205765        -0.624973
# 2  0.064204         -0.737204                    -0.205765        -0.624973
# 3  0.064204         -0.737204                    -0.205765        -0.624973
# 4  0.064204         -0.737204                    -0.205765        -0.624973

# %% [markdown]
# **exurb result:**

# %%
scores_desc_rc3=np.flip(x_rc3_scores[x_rc3_i])
cols_desc_rc3=list(x_rc3_scaled.iloc[:3,x_rc3_i].columns) #remove last index?
cols_desc_rc3.reverse()
res_df_rc3=pd.DataFrame({'Variable':cols_desc_rc3,
        'ANOVA corr':scores_desc_rc3}).iloc[1:,:]
# dfi.export(res_df_rc3, '/Users/yapinghe/Desktop/broadband research/ruca_exurb_anova_corr.png')
# res_df_rc3.to_csv('ruca_exurb_anova_corr.csv')
res_df_rc3
# Out:
#                                           Variable    ANOVA corr
# 1                                  pct_deeppov_raw  12439.072249
# 2                      pct_NH_AIAN_alone_ACS_14_18  12218.789070
# 3                                 pct_belowpov_raw  11312.327061
# 4                                             lfpr   9166.453516
# 5                                            index   8992.684884
# 6                         avg_Agg_HH_INC_ACS_14_18   8698.249251
# 7                  Religious congregations p 1,000   8456.089510
# 8                                             rank   7818.054833
# 9                    pct_Prs_Blw_Pov_Lev_ACS_14_18   7137.256873
# 10                           pct_College_ACS_14_18   5796.517631
# 11                       % women currently married   5657.758612
# 12                          pct_RURAL_POP_CEN_2010   5504.221600
# 13                                         lbw_raw   5414.326846
# 14                    pct_NH_White_alone_ACS_14_18   5334.454346
# 15                       pct_Not_HS_Grad_ACS_14_18   5229.149945
# 16                  pct_URBAN_CLUSTER_POP_CEN_2010   5034.309186
# 17                  Land Area (square miles), 2010   4550.496801
# 18                                    pct_bachmore   4474.684579
# 19                            Institutional Health   4335.983416
# 20                          Tract Population, 2010   3968.170748
# 21                                    Family Unity   3934.624453
# 22                   Excluding Collective Efficacy   3882.276299
# 23                  Mail-back census response rate   3728.950516
# 24      Population Density (per square mile), 2010   3700.701556
# 25                                    life_exp_raw   3477.495526
# 26                   avg_Agg_House_Value_ACS_14_18   3411.568125
# 27                                        pct_lths   3260.575015
# 28                         pct_Othr_Lang_ACS_14_18   3174.486573
# 29                      pct_Vacant_Units_ACS_14_18   3153.251739
# 30                   % children with single parent   3099.021309
# 31                              County-Level Index   2884.423451
# 32                      Requiring all 4 Subindices   2884.423451
# 33                        Tot_Population_ACS_14_18   2839.216785
# 34                            pct_ENG_VW_ACS_14_18   2733.538293
# 35  Non-religious non-profit organizations p 1,000   2691.781136
# 36             Confidence in Institutions Subindex   2240.933527
# 37                                     reservation   2152.281532
# 38                      pct_NH_Blk_alone_ACS_14_18   2053.721564
# 39                                           urban   1904.251644
# 40                                           rural   1904.251644
# 41  Presidential election voting rate, 2012 & 2016   1569.449376
# 42                          pct_Hispanic_ACS_14_18   1361.108477
# 43                   pct_Diff_HU_1yr_Ago_ACS_14_18   1115.512553
# 44                     % births to unmarried women    904.301852
# 45                    pct_NH_Asian_alone_ACS_14_18    546.269460
# 46                 pct_URBANIZED_AREA_POP_CEN_2010    499.754520
# 47                   avg_Tot_Prns_in_HHD_ACS_14_18    462.241763
# 48          Secondary RUCA Code, 2010 (see errata)    425.577182
# 49                          Primary RUCA Code 2010    425.577182
# 50              Informal Civic Engagement Subindex    403.812236
# 51                      pct_NH_SOR_alone_ACS_14_18    397.272166
# 52                                    mobility_raw    312.503876
# 53                                         tot_pop    230.494485
# 54                             Collective Efficacy    178.291487
# 55                        Violent Crimes p 100,000    178.291464
# 56                      pct_PUB_ASST_INC_ACS_14_18    165.474738
# 57                    pct_NH_NHOPI_alone_ACS_14_18     17.363040
# 58                                Community Health     15.001421
# 59                   pct_Recent_Built_HU_ACS_14_18      1.888382

# %% [markdown]
# repeat for rural category:

# %%
# rc4
x_rc4_res=anova_df_2(x_rc4_scaled,y1_rc4,4)
x_4_rc4=x_rc4_res[0]
x_rc4_scores=x_rc4_res[1]
x_rc4_i=x_rc4_res[2]
x_4_rc4.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [23 59] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    Requiring all 4 Subindices  Excluding Collective Efficacy  \
# 0                   -1.604751                      -1.509892
# 1                   -1.604751                      -1.509892
# 2                   -1.604751                      -1.509892
# 3                   -1.604751                      -1.509892
# 4                   -1.604751                      -1.509892
#
#    Institutional Health  Confidence in Institutions Subindex
# 0             -0.486549                            -0.007762
# 1             -0.486549                            -0.007762
# 2             -0.486549                            -0.007762
# 3             -0.486549                            -0.007762
# 4             -0.486549                            -0.007762

# %%
x_rc4_scores,x_rc4_i
# Out:
# (array([3.66161238e-01, 1.81463737e+02, 1.34585672e+03, 1.50276026e+03,
#         1.13512755e+04, 3.56099488e+03, 4.69239223e+03, 2.32235420e+04,
#         1.51601519e+03, 1.77612832e+04, 2.13797483e+03, 1.62090493e+01,
#         2.07676186e+02, 1.89137082e+04, 7.28779238e+03, 8.41504892e+03,
#         7.61832272e+03, 1.64601459e+04, 1.45043480e+04, 2.93780278e+01,
#         2.06054350e+03, 6.38552386e+01, 2.56655312e+03,            nan,
#         1.07892068e+00, 3.54645874e+02, 1.81924053e+04, 1.79463745e+04,
#         1.69861278e+04, 2.08545720e+04, 9.26738226e+03, 1.98291430e+04,
#         1.40608954e+04, 1.60489792e+04, 7.95735403e+03, 2.54374299e+03,
#         2.54374299e+03, 2.80514056e+03, 1.10729067e+03, 1.21434764e+04,
#         1.46601310e+04, 5.78349372e+03, 2.98217562e+04, 2.98217562e+04,
#         3.31825561e+04, 1.36507336e+04, 6.69088302e+03, 4.56042561e+04,
#         6.12078692e+03, 4.36336193e+03, 1.49803335e+04, 1.02667780e+04,
#         7.78493825e+03, 6.98443930e+02, 1.35227367e+04, 1.87253830e+04,
#         1.51665486e+04, 3.42602833e+04, 6.12078601e+03,            nan]),
#  array([ 0, 24, 11, 19, 21,  1, 12, 25, 53, 38,  2,  3,  8, 20, 10, 36, 35,
#         22, 37,  5, 49,  6, 41, 58, 48, 46, 14, 16, 52, 34, 15, 30, 51,  4,
#         39, 54, 45, 32, 18, 40, 50, 56, 33, 17, 28,  9, 27, 26, 55, 13, 31,
#         29,  7, 43, 42, 44, 57, 47, 23, 59]))

# %%
x_10_rc4=x_rc4_scaled.iloc[:,x_rc4_i[-12:-2]] # remove 2 nan index
x_10_rc4.head()
# Out:
#    Presidential election voting rate, 2012 & 2016  pct_Othr_Lang_ACS_14_18  \
# 0                                       -0.703898                -0.134837
# 1                                       -0.703898                -0.134837
# 2                                       -0.703898                -0.134837
# 3                                       -0.703898                -0.134837
# 4                                       -0.703898                -0.134837
#
#    pct_belowpov_raw     index  pct_NH_White_alone_ACS_14_18  \
# 0          1.986277 -2.251683                     -1.342512
# 1          1.986277 -2.251683                     -1.342512
# 2          1.986277 -2.251683                     -1.342512
# 3          1.986277 -2.251683                     -1.342512
# 4          1.986277 -2.251683                     -1.342512
#
#    Requiring all 4 Subindices  County-Level Index  \
# 0                   -1.604751           -1.604751
# 1                   -1.604751           -1.604751
# 2                   -1.604751           -1.604751
# 3                   -1.604751           -1.604751
# 4                   -1.604751           -1.604751
#
#    Excluding Collective Efficacy  Confidence in Institutions Subindex  \
# 0                      -1.509892                            -0.007762
# 1                      -1.509892                            -0.007762
# 2                      -1.509892                            -0.007762
# 3                      -1.509892                            -0.007762
# 4                      -1.509892                            -0.007762
#
#    Institutional Health
# 0             -0.486549
# 1             -0.486549
# 2             -0.486549
# 3             -0.486549
# 4             -0.486549

# %% [markdown]
# **rural result:**

# %%
scores_desc_rc4=np.flip(x_rc4_scores[x_rc4_i])
cols_desc_rc4=list(x_rc4_scaled.iloc[:3,x_rc4_i].columns) #remove last index?
cols_desc_rc4.reverse()
res_df_rc4=pd.DataFrame({'Variable':cols_desc_rc4,
        'ANOVA corr':scores_desc_rc4}).iloc[2:,:]
# dfi.export(res_df_rc4, '/Users/yapinghe/Desktop/broadband research/ruca_rural_anova_corr.png')
# res_df_rc4.to_csv('ruca_rural_anova_corr.csv')
res_df_rc4
# Out:
#                                           Variable    ANOVA corr
# 2                             Institutional Health  45604.256102
# 3              Confidence in Institutions Subindex  34260.283314
# 4                    Excluding Collective Efficacy  33182.556115
# 5                               County-Level Index  29821.756172
# 6                       Requiring all 4 Subindices  29821.756172
# 7                     pct_NH_White_alone_ACS_14_18  23223.541951
# 8                                            index  20854.572037
# 9                                 pct_belowpov_raw  19829.143025
# 10                         pct_Othr_Lang_ACS_14_18  18913.708155
# 11  Presidential election voting rate, 2012 & 2016  18725.382955
# 12                  Land Area (square miles), 2010  18192.405317
# 13      Population Density (per square mile), 2010  17946.374540
# 14                     pct_NH_AIAN_alone_ACS_14_18  17761.283153
# 15                                            rank  16986.127769
# 16                        avg_Agg_HH_INC_ACS_14_18  16460.145943
# 17                                    life_exp_raw  16048.979243
# 18                  Mail-back census response rate  15166.548634
# 19                       % women currently married  14980.333535
# 20                                            lfpr  14660.130973
# 21                   pct_Prs_Blw_Pov_Lev_ACS_14_18  14504.348022
# 22                                 pct_deeppov_raw  14060.895402
# 23                                    Family Unity  13650.733571
# 24              Informal Civic Engagement Subindex  13522.736729
# 25                                        pct_lths  12143.476440
# 26                   avg_Tot_Prns_in_HHD_ACS_14_18  11351.275474
# 27                   % children with single parent  10266.777984
# 28                                    mobility_raw   9267.382258
# 29                       pct_Not_HS_Grad_ACS_14_18   8415.048921
# 30                                         lbw_raw   7957.354027
# 31  Non-religious non-profit organizations p 1,000   7784.938250
# 32                           pct_College_ACS_14_18   7618.322722
# 33                            pct_ENG_VW_ACS_14_18   7287.792379
# 34                                Community Health   6690.883023
# 35                             Collective Efficacy   6120.786925
# 36                        Violent Crimes p 100,000   6120.786007
# 37                                    pct_bachmore   5783.493721
# 38                          pct_Hispanic_ACS_14_18   4692.392231
# 39                     % births to unmarried women   4363.361927
# 40                      pct_Vacant_Units_ACS_14_18   3560.994882
# 41                                     reservation   2805.140559
# 42                   avg_Agg_House_Value_ACS_14_18   2566.553121
# 43                                           urban   2543.742992
# 44                                           rural   2543.742992
# 45                    pct_NH_Asian_alone_ACS_14_18   2137.974833
# 46                   pct_Diff_HU_1yr_Ago_ACS_14_18   2060.543505
# 47                      pct_NH_Blk_alone_ACS_14_18   1516.015187
# 48                          pct_RURAL_POP_CEN_2010   1502.760256
# 49                  pct_URBAN_CLUSTER_POP_CEN_2010   1345.856722
# 50                                         tot_pop   1107.290673
# 51                 Religious congregations p 1,000    698.443930
# 52                          Tract Population, 2010    354.645874
# 53                      pct_NH_SOR_alone_ACS_14_18    207.676186
# 54                 pct_URBANIZED_AREA_POP_CEN_2010    181.463737
# 55                   pct_Recent_Built_HU_ACS_14_18     63.855239
# 56                      pct_PUB_ASST_INC_ACS_14_18     29.378028
# 57                    pct_NH_NHOPI_alone_ACS_14_18     16.209049
# 58          Secondary RUCA Code, 2010 (see errata)      1.078921
# 59                        Tot_Population_ACS_14_18      0.366161

# %%
np.nanmean(x_rc1_scores),np.nanmean(x_rc2_scores),np.nanmean(x_rc3_scores),np.nanmean(x_rc4_scores)
# Out:
# (46221.38597736124, 22360.8489690902, 3556.966283982469, 10677.341447566228)

# %%
# on avg, highest anova f scores for rc1, then rc2, rc4, rc3

# %% [markdown]
# Repeat for all categories for y2 (AnyProviderWith100/10):

# %%
# repeat for y2
x_rc1_res_y2=anova_df_2(x_rc1_scaled,y2_rc1,10)
x_10_rc1_y2=x_rc1_res_y2[0]
x_rc1_scores_y2=x_rc1_res_y2[1]
x_rc1_i_y2=x_rc1_res_y2[2]
x_10_rc1_y2.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [59] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    pct_URBANIZED_AREA_POP_CEN_2010  pct_RURAL_POP_CEN_2010  \
# 0                         0.139383                0.455694
# 1                         0.139383                0.455694
# 2                         0.139383                0.455694
# 3                         0.139383                0.455694
# 4                         0.139383                0.455694
#
#    Primary RUCA Code 2010  Secondary RUCA Code, 2010 (see errata)  \
# 0               -0.538984                               -0.540137
# 1               -0.538984                               -0.540137
# 2               -0.538984                               -0.540137
# 3               -0.538984                               -0.540137
# 4               -0.538984                               -0.540137
#
#    Land Area (square miles), 2010  Population Density (per square mile), 2010  \
# 0                       -0.146724                                   -0.524173
# 1                       -0.146724                                   -0.524173
# 2                       -0.146724                                   -0.524173
# 3                       -0.146724                                   -0.524173
# 4                       -0.146724                                   -0.524173
#
#       urban     rural  pct_bachmore  Religious congregations p 1,000
# 0  0.504483 -0.504483     -0.394264                         0.935834
# 1  0.504483 -0.504483     -0.394264                         0.935834
# 2  0.504483 -0.504483     -0.394264                         0.935834
# 3  0.504483 -0.504483     -0.394264                         0.935834
# 4  0.504483 -0.504483     -0.394264                         0.935834

# %%
x_rc1_scores_y2,x_rc1_i_y2
# Out:
# (array([7.44027467e+02, 4.22683376e+05, 4.85125780e+04, 6.26742192e+05,
#         2.28306484e+02, 5.45783287e+04, 4.76936836e+03, 4.23012215e+03,
#         1.35413910e+04, 4.69561319e+04, 3.72200891e+04, 3.97398366e+02,
#         3.26838324e+03, 2.11148291e+03, 2.25440792e+02, 2.27935558e+04,
#         6.61696095e+04, 2.63816173e+04, 4.60617175e+03, 6.01909250e+02,
#         9.52577706e+00, 5.73347686e+03, 1.56753613e+04, 3.59817631e+05,
#         3.60489560e+05, 4.18403957e+03, 2.31889333e+05, 1.40348242e+05,
#         1.05075896e+04, 1.27773806e+04, 6.49262527e+04, 4.96447317e+04,
#         3.08849198e+04, 6.15605125e+04, 1.65619060e+03, 2.23142209e+05,
#         2.23142209e+05, 1.49641264e+04, 5.58365231e+04, 6.48568600e+04,
#         1.05821519e+05, 1.73349898e+05, 4.45190025e+01, 4.45190025e+01,
#         4.54219999e+03, 3.94139151e+00, 5.28474991e+04, 6.73677388e+04,
#         1.15001376e+04, 5.72627037e+03, 7.05814433e+03, 1.37943868e+02,
#         1.69630130e+03, 2.34788804e+05, 7.61687233e+03, 7.29568269e+04,
#         1.09053618e+05, 4.74105696e+03, 1.15001360e+04,            nan]),
#  array([45, 20, 42, 43, 51, 14,  4, 11, 19,  0, 34, 52, 13, 12, 25,  7, 44,
#         18, 57,  6, 49, 21, 50, 54, 28, 58, 48, 29,  8, 37, 22, 15, 17, 32,
#         10,  9,  2, 31, 46,  5, 38, 33, 39, 30, 16, 47, 55, 40, 56, 27, 41,
#         35, 36, 26, 53, 23, 24,  1,  3, 59]))

# %% [markdown]
# **core result, y2:**

# %%
scores_desc_rc1_y2=np.flip(x_rc1_scores_y2[x_rc1_i_y2])
cols_desc_rc1_y2=list(x_rc1_scaled.iloc[:3,x_rc1_i_y2].columns) #remove last index?
cols_desc_rc1_y2.reverse()
res_df_rc1_y2=pd.DataFrame({'Variable':cols_desc_rc1_y2,
        'ANOVA corr':scores_desc_rc1_y2}).iloc[1:,:]
# dfi.export(res_df_rc1_y2, '/Users/yapinghe/Desktop/broadband research/ruca_core_anova_corr_y2.png')
# res_df_rc1_y2.to_csv('ruca_core_anova_corr_y2.csv')
res_df_rc1_y2
# Out:
#                                           Variable     ANOVA corr
# 1                           pct_RURAL_POP_CEN_2010  626742.191612
# 2                  pct_URBANIZED_AREA_POP_CEN_2010  422683.375775
# 3           Secondary RUCA Code, 2010 (see errata)  360489.560130
# 4                           Primary RUCA Code 2010  359817.630824
# 5                  Religious congregations p 1,000  234788.803807
# 6                   Land Area (square miles), 2010  231889.332685
# 7                                            rural  223142.209231
# 8                                            urban  223142.209231
# 9                                     pct_bachmore  173349.897889
# 10      Population Density (per square mile), 2010  140348.241511
# 11                  Mail-back census response rate  109053.617511
# 12                                            lfpr  105821.519384
# 13  Presidential election voting rate, 2012 & 2016   72956.826903
# 14                            Institutional Health   67367.738806
# 15                           pct_College_ACS_14_18   66169.609544
# 16                                    mobility_raw   64926.252727
# 17                                        pct_lths   64856.859967
# 18                                    life_exp_raw   61560.512519
# 19                                         tot_pop   55836.523096
# 20                      pct_Vacant_Units_ACS_14_18   54578.328654
# 21                                Community Health   52847.499086
# 22                                pct_belowpov_raw   49644.731748
# 23                  pct_URBAN_CLUSTER_POP_CEN_2010   48512.577981
# 24                     pct_NH_AIAN_alone_ACS_14_18   46956.131876
# 25                    pct_NH_Asian_alone_ACS_14_18   37220.089101
# 26                                 pct_deeppov_raw   30884.919824
# 27                        avg_Agg_HH_INC_ACS_14_18   26381.617257
# 28                       pct_Not_HS_Grad_ACS_14_18   22793.555822
# 29                   avg_Agg_House_Value_ACS_14_18   15675.361260
# 30                                     reservation   14964.126410
# 31                      pct_NH_Blk_alone_ACS_14_18   13541.391016
# 32                                           index   12777.380566
# 33                             Collective Efficacy   11500.137641
# 34                        Violent Crimes p 100,000   11500.135971
# 35                                            rank   10507.589568
# 36              Informal Civic Engagement Subindex    7616.872334
# 37                       % women currently married    7058.144330
# 38                   pct_Recent_Built_HU_ACS_14_18    5733.476862
# 39                     % births to unmarried women    5726.270372
# 40                          pct_Hispanic_ACS_14_18    4769.368362
# 41             Confidence in Institutions Subindex    4741.056959
# 42                   pct_Prs_Blw_Pov_Lev_ACS_14_18    4606.171746
# 43                   Excluding Collective Efficacy    4542.199992
# 44                    pct_NH_White_alone_ACS_14_18    4230.122152
# 45                          Tract Population, 2010    4184.039572
# 46                      pct_NH_SOR_alone_ACS_14_18    3268.383242
# 47                         pct_Othr_Lang_ACS_14_18    2111.482910
# 48  Non-religious non-profit organizations p 1,000    1696.301301
# 49                                         lbw_raw    1656.190598
# 50                        Tot_Population_ACS_14_18     744.027467
# 51                      pct_PUB_ASST_INC_ACS_14_18     601.909250
# 52                    pct_NH_NHOPI_alone_ACS_14_18     397.398366
# 53                   avg_Tot_Prns_in_HHD_ACS_14_18     228.306484
# 54                            pct_ENG_VW_ACS_14_18     225.440792
# 55                   % children with single parent     137.943868
# 56                      Requiring all 4 Subindices      44.519003
# 57                              County-Level Index      44.519003
# 58                   pct_Diff_HU_1yr_Ago_ACS_14_18       9.525777
# 59                                    Family Unity       3.941392

# %%
#rc2
x_rc2_res_y2=anova_df_2(x_rc2_scaled,y2_rc2,10)
x_10_rc2_y2=x_rc2_res_y2[0]
x_rc2_scores_y2=x_rc2_res_y2[1]
x_rc2_i_y2=x_rc2_res_y2[2]
x_10_rc2_y2.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [59] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    pct_URBANIZED_AREA_POP_CEN_2010  pct_URBAN_CLUSTER_POP_CEN_2010  \
# 0                         1.074533                       -0.404258
# 1                         1.074533                       -0.404258
# 2                         1.074533                       -0.404258
# 3                         1.074533                       -0.404258
# 4                         1.074533                       -0.404258
#
#    pct_RURAL_POP_CEN_2010  Land Area (square miles), 2010  \
# 0               -0.216133                       -0.349854
# 1               -0.216133                       -0.349854
# 2               -0.216133                       -0.349854
# 3               -0.216133                       -0.349854
# 4               -0.216133                       -0.349854
#
#    Population Density (per square mile), 2010     urban     rural  \
# 0                                   -0.153644  0.919662 -0.919662
# 1                                   -0.153644  0.919662 -0.919662
# 2                                   -0.153644  0.919662 -0.919662
# 3                                   -0.153644  0.919662 -0.919662
# 4                                   -0.153644  0.919662 -0.919662
#
#    pct_bachmore  Religious congregations p 1,000  \
# 0      0.251263                         0.042894
# 1      0.251263                         0.042894
# 2      0.251263                         0.042894
# 3      0.251263                         0.042894
# 4      0.251263                         0.042894
#
#    Mail-back census response rate
# 0                        0.518921
# 1                        0.518921
# 2                        0.518921
# 3                        0.518921
# 4                        0.518921

# %%
x_rc2_scores_y2,x_rc2_i_y2
# Out:
# (array([3.00834716e+04, 4.47554983e+04, 7.11360477e+04, 1.27333045e+05,
#         2.95953959e+03, 2.93767653e+04, 1.08747549e+04, 1.92240572e+04,
#         7.56291029e+02, 3.13794950e+04, 1.18317316e+04, 6.33992236e+01,
#         8.13329309e+02, 1.99383400e+04, 1.42384071e+04, 9.92341309e+03,
#         2.05880493e+04, 8.44845539e+03, 4.30800514e+03, 6.73894012e+02,
#         3.75191640e+03, 2.69630626e-01, 2.47202930e+03, 2.89635062e+04,
#         2.88867152e+04, 2.47917569e+04, 6.15442487e+04, 5.89889569e+04,
#         2.40561143e+03, 2.93357730e+03, 1.71118392e+04, 1.59889123e+04,
#         1.06265357e+04, 8.93533174e+03, 3.30727313e+02, 3.34252341e+04,
#         3.34252341e+04, 6.35694799e+03, 8.45194672e+03, 1.87445943e+04,
#         1.30533792e+04, 3.24576843e+04, 2.86339822e+03, 2.86339822e+03,
#         4.68936575e+03, 1.55569427e+03, 1.89826050e+04, 3.02244378e+04,
#         7.93346956e+01, 1.87370886e+03, 7.57793709e+02, 1.08069726e+03,
#         3.24915368e+03, 4.76052769e+04, 1.27284625e+03, 2.84357420e+04,
#         5.97047616e+04, 1.05602024e+03, 7.93347431e+01,            nan]),
#  array([21, 11, 48, 58, 34, 19,  8, 50, 12, 57, 51, 54, 45, 49, 28, 22, 42,
#         43, 29,  4, 52, 20, 18, 44, 37, 17, 38, 33, 15, 32,  6, 10, 40, 14,
#         31, 30, 39, 46,  7, 13, 16, 25, 55, 24, 23,  5,  0, 47,  9, 41, 36,
#         35,  1, 53, 27, 56, 26,  2,  3, 59]))

# %% [markdown]
# **suburb result, y2:**

# %%
scores_desc_rc2_y2=np.flip(x_rc2_scores_y2[x_rc2_i_y2])
cols_desc_rc2_y2=list(x_rc2_scaled.iloc[:3,x_rc2_i_y2].columns) #remove last index?
cols_desc_rc2_y2.reverse()
res_df_rc2_y2=pd.DataFrame({'Variable':cols_desc_rc2_y2,
        'ANOVA corr':scores_desc_rc2_y2}).iloc[1:,:]
# dfi.export(res_df_rc2_y2, '/Users/yapinghe/Desktop/broadband research/ruca_suburb_anova_corr_y2.png')
# res_df_rc2_y2.to_csv('ruca_suburb_anova_corr_y2.csv')
res_df_rc2_y2
# Out:
#                                           Variable     ANOVA corr
# 1                           pct_RURAL_POP_CEN_2010  127333.044679
# 2                   pct_URBAN_CLUSTER_POP_CEN_2010   71136.047659
# 3                   Land Area (square miles), 2010   61544.248660
# 4                   Mail-back census response rate   59704.761596
# 5       Population Density (per square mile), 2010   58988.956924
# 6                  Religious congregations p 1,000   47605.276865
# 7                  pct_URBANIZED_AREA_POP_CEN_2010   44755.498338
# 8                                            urban   33425.234090
# 9                                            rural   33425.234090
# 10                                    pct_bachmore   32457.684269
# 11                     pct_NH_AIAN_alone_ACS_14_18   31379.495049
# 12                            Institutional Health   30224.437834
# 13                        Tot_Population_ACS_14_18   30083.471573
# 14                      pct_Vacant_Units_ACS_14_18   29376.765315
# 15                          Primary RUCA Code 2010   28963.506180
# 16          Secondary RUCA Code, 2010 (see errata)   28886.715181
# 17  Presidential election voting rate, 2012 & 2016   28435.741961
# 18                          Tract Population, 2010   24791.756861
# 19                           pct_College_ACS_14_18   20588.049341
# 20                         pct_Othr_Lang_ACS_14_18   19938.339953
# 21                    pct_NH_White_alone_ACS_14_18   19224.057233
# 22                                Community Health   18982.604992
# 23                                        pct_lths   18744.594319
# 24                                    mobility_raw   17111.839248
# 25                                pct_belowpov_raw   15988.912315
# 26                            pct_ENG_VW_ACS_14_18   14238.407146
# 27                                            lfpr   13053.379185
# 28                    pct_NH_Asian_alone_ACS_14_18   11831.731619
# 29                          pct_Hispanic_ACS_14_18   10874.754892
# 30                                 pct_deeppov_raw   10626.535733
# 31                       pct_Not_HS_Grad_ACS_14_18    9923.413089
# 32                                    life_exp_raw    8935.331736
# 33                                         tot_pop    8451.946721
# 34                        avg_Agg_HH_INC_ACS_14_18    8448.455390
# 35                                     reservation    6356.947991
# 36                   Excluding Collective Efficacy    4689.365746
# 37                   pct_Prs_Blw_Pov_Lev_ACS_14_18    4308.005143
# 38                   pct_Diff_HU_1yr_Ago_ACS_14_18    3751.916405
# 39  Non-religious non-profit organizations p 1,000    3249.153678
# 40                   avg_Tot_Prns_in_HHD_ACS_14_18    2959.539586
# 41                                           index    2933.577296
# 42                      Requiring all 4 Subindices    2863.398223
# 43                              County-Level Index    2863.398223
# 44                   avg_Agg_House_Value_ACS_14_18    2472.029304
# 45                                            rank    2405.611427
# 46                     % births to unmarried women    1873.708856
# 47                                    Family Unity    1555.694272
# 48              Informal Civic Engagement Subindex    1272.846254
# 49                   % children with single parent    1080.697261
# 50             Confidence in Institutions Subindex    1056.020237
# 51                      pct_NH_SOR_alone_ACS_14_18     813.329309
# 52                       % women currently married     757.793709
# 53                      pct_NH_Blk_alone_ACS_14_18     756.291029
# 54                      pct_PUB_ASST_INC_ACS_14_18     673.894012
# 55                                         lbw_raw     330.727313
# 56                        Violent Crimes p 100,000      79.334743
# 57                             Collective Efficacy      79.334696
# 58                    pct_NH_NHOPI_alone_ACS_14_18      63.399224
# 59                   pct_Recent_Built_HU_ACS_14_18       0.269631

# %%
#rc3
x_rc3_res_y2=anova_df_2(x_rc3_scaled,y2_rc3,10)
x_10_rc3_y2=x_rc3_res_y2[0]
x_rc3_scores_y2=x_rc3_res_y2[1]
x_rc3_i_y2=x_rc3_res_y2[2]
x_10_rc3_y2.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [59] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    pct_URBAN_CLUSTER_POP_CEN_2010  pct_RURAL_POP_CEN_2010  \
# 0                       -0.319607                0.329467
# 1                       -0.319607                0.329467
# 2                       -0.319607                0.329467
# 3                       -0.319607                0.329467
# 4                       -0.319607                0.329467
#
#    pct_NH_AIAN_alone_ACS_14_18  Tract Population, 2010  \
# 0                    -0.205765               -0.183551
# 1                    -0.205765               -0.183551
# 2                    -0.205765               -0.183551
# 3                    -0.205765               -0.183551
# 4                    -0.205765               -0.183551
#
#    Land Area (square miles), 2010  Population Density (per square mile), 2010  \
# 0                        0.726491                                   -0.318411
# 1                        0.726491                                   -0.318411
# 2                        0.726491                                   -0.318411
# 3                        0.726491                                   -0.318411
# 4                        0.726491                                   -0.318411
#
#    pct_belowpov_raw  pct_deeppov_raw  pct_bachmore  \
# 0         -0.737204        -0.624973      2.019242
# 1         -0.737204        -0.624973      2.019242
# 2         -0.737204        -0.624973      2.019242
# 3         -0.737204        -0.624973      2.019242
# 4         -0.737204        -0.624973      2.019242
#
#    Religious congregations p 1,000
# 0                        -0.668572
# 1                        -0.668572
# 2                        -0.668572
# 3                        -0.668572
# 4                        -0.668572

# %%
x_rc3_scores_y2,x_rc3_i_y2
# Out:
# (array([2.65968466e+03, 6.74004276e+02, 1.06456214e+04, 1.13903203e+04,
#         1.95476506e+03, 7.65650044e+02, 6.24833558e+02, 3.65381633e+03,
#         1.09125563e+02, 4.60565058e+03, 6.73916282e+02, 2.04588454e+02,
#         5.33488999e+02, 3.89569161e+03, 4.14442072e+03, 3.63754497e+03,
#         4.35163634e+03, 1.50910570e+03, 1.87184977e+03, 4.97230028e+01,
#         1.27905177e+03, 7.32502090e+02, 6.61427893e+02, 7.05001300e+02,
#         7.05001300e+02, 5.15266236e+03, 7.55334873e+03, 8.24409789e+03,
#         2.19964179e+03, 2.23436926e+03, 4.99680262e+02, 5.80409472e+03,
#         4.73212492e+03, 1.67128728e+03, 7.46323060e+01, 1.55700420e+03,
#         1.55700420e+03, 1.04279456e+03, 3.21666700e+01, 4.40822044e+03,
#         2.68699068e+03, 7.39520616e+03, 5.04794188e+02, 5.04794188e+02,
#         9.20611713e+02, 1.34660486e+02, 6.43275570e+02, 3.57775879e+03,
#         2.12043023e-02, 1.51539027e+00, 3.38376667e+02, 1.48251293e+02,
#         1.20238102e+02, 6.66087607e+03, 1.85500619e+02, 3.28220864e+03,
#         4.26508792e+03, 2.63107192e+02, 2.12039527e-02,            nan]),
#  array([58, 48, 49, 38, 19, 34,  8, 52, 45, 51, 54, 11, 57, 50, 30, 43, 42,
#         12,  6, 46, 22, 10,  1, 23, 24, 21,  5, 44, 37, 20, 17, 36, 35, 33,
#         18,  4, 28, 29,  0, 40, 55, 47, 15,  7, 13, 14, 56, 16, 39,  9, 32,
#         25, 31, 53, 41, 26, 27,  2,  3, 59]))

# %% [markdown]
# **exurb result, y2:**

# %%
scores_desc_rc3_y2=np.flip(x_rc3_scores_y2[x_rc3_i_y2])
cols_desc_rc3_y2=list(x_rc3_scaled.iloc[:3,x_rc3_i_y2].columns) #remove last index?
cols_desc_rc3_y2.reverse()
res_df_rc3_y2=pd.DataFrame({'Variable':cols_desc_rc3_y2,
        'ANOVA corr':scores_desc_rc3_y2}).iloc[1:,:]
# dfi.export(res_df_rc3_y2, '/Users/yapinghe/Desktop/broadband research/ruca_exurb_anova_corr_y2.png')
# res_df_rc3_y2.to_csv('ruca_exurb_anova_corr_y2.csv')
res_df_rc3_y2
# Out:
#                                           Variable    ANOVA corr
# 1                           pct_RURAL_POP_CEN_2010  11390.320282
# 2                   pct_URBAN_CLUSTER_POP_CEN_2010  10645.621368
# 3       Population Density (per square mile), 2010   8244.097890
# 4                   Land Area (square miles), 2010   7553.348731
# 5                                     pct_bachmore   7395.206155
# 6                  Religious congregations p 1,000   6660.876065
# 7                                 pct_belowpov_raw   5804.094720
# 8                           Tract Population, 2010   5152.662355
# 9                                  pct_deeppov_raw   4732.124916
# 10                     pct_NH_AIAN_alone_ACS_14_18   4605.650579
# 11                                        pct_lths   4408.220438
# 12                           pct_College_ACS_14_18   4351.636342
# 13                  Mail-back census response rate   4265.087922
# 14                            pct_ENG_VW_ACS_14_18   4144.420717
# 15                         pct_Othr_Lang_ACS_14_18   3895.691610
# 16                    pct_NH_White_alone_ACS_14_18   3653.816332
# 17                       pct_Not_HS_Grad_ACS_14_18   3637.544966
# 18                            Institutional Health   3577.758789
# 19  Presidential election voting rate, 2012 & 2016   3282.208641
# 20                                            lfpr   2686.990684
# 21                        Tot_Population_ACS_14_18   2659.684658
# 22                                           index   2234.369262
# 23                                            rank   2199.641792
# 24                   avg_Tot_Prns_in_HHD_ACS_14_18   1954.765057
# 25                   pct_Prs_Blw_Pov_Lev_ACS_14_18   1871.849774
# 26                                    life_exp_raw   1671.287276
# 27                                           urban   1557.004198
# 28                                           rural   1557.004198
# 29                        avg_Agg_HH_INC_ACS_14_18   1509.105701
# 30                   pct_Diff_HU_1yr_Ago_ACS_14_18   1279.051770
# 31                                     reservation   1042.794563
# 32                   Excluding Collective Efficacy    920.611713
# 33                      pct_Vacant_Units_ACS_14_18    765.650044
# 34                   pct_Recent_Built_HU_ACS_14_18    732.502090
# 35          Secondary RUCA Code, 2010 (see errata)    705.001300
# 36                          Primary RUCA Code 2010    705.001300
# 37                 pct_URBANIZED_AREA_POP_CEN_2010    674.004276
# 38                    pct_NH_Asian_alone_ACS_14_18    673.916282
# 39                   avg_Agg_House_Value_ACS_14_18    661.427893
# 40                                Community Health    643.275570
# 41                          pct_Hispanic_ACS_14_18    624.833558
# 42                      pct_NH_SOR_alone_ACS_14_18    533.488999
# 43                              County-Level Index    504.794188
# 44                      Requiring all 4 Subindices    504.794188
# 45                                    mobility_raw    499.680262
# 46                       % women currently married    338.376667
# 47             Confidence in Institutions Subindex    263.107192
# 48                    pct_NH_NHOPI_alone_ACS_14_18    204.588454
# 49              Informal Civic Engagement Subindex    185.500619
# 50                   % children with single parent    148.251293
# 51                                    Family Unity    134.660486
# 52  Non-religious non-profit organizations p 1,000    120.238102
# 53                      pct_NH_Blk_alone_ACS_14_18    109.125563
# 54                                         lbw_raw     74.632306
# 55                      pct_PUB_ASST_INC_ACS_14_18     49.723003
# 56                                         tot_pop     32.166670
# 57                     % births to unmarried women      1.515390
# 58                             Collective Efficacy      0.021204
# 59                        Violent Crimes p 100,000      0.021204

# %%
#rc4
x_rc4_res_y2=anova_df_2(x_rc4_scaled,y2_rc4,10)
x_10_rc4_y2=x_rc4_res_y2[0]
x_rc4_scores_y2=x_rc4_res_y2[1]
x_rc4_i_y2=x_rc4_res_y2[2]
x_10_rc4_y2.head()
# Out:
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [23 59] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /Users/yapinghe/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    avg_Tot_Prns_in_HHD_ACS_14_18  pct_Hispanic_ACS_14_18  \
# 0                      -1.033981                -0.54038
# 1                      -1.033981                -0.54038
# 2                      -1.033981                -0.54038
# 3                      -1.033981                -0.54038
# 4                      -1.033981                -0.54038
#
#    pct_NH_White_alone_ACS_14_18  pct_Othr_Lang_ACS_14_18  \
# 0                     -1.342512                -0.134837
# 1                     -1.342512                -0.134837
# 2                     -1.342512                -0.134837
# 3                     -1.342512                -0.134837
# 4                     -1.342512                -0.134837
#
#    Population Density (per square mile), 2010  County-Level Index  \
# 0                                   -0.294442           -1.604751
# 1                                   -0.294442           -1.604751
# 2                                   -0.294442           -1.604751
# 3                                   -0.294442           -1.604751
# 4                                   -0.294442           -1.604751
#
#    Requiring all 4 Subindices  Excluding Collective Efficacy  \
# 0                   -1.604751                      -1.509892
# 1                   -1.604751                      -1.509892
# 2                   -1.604751                      -1.509892
# 3                   -1.604751                      -1.509892
# 4                   -1.604751                      -1.509892
#
#    Institutional Health  Confidence in Institutions Subindex
# 0             -0.486549                            -0.007762
# 1             -0.486549                            -0.007762
# 2             -0.486549                            -0.007762
# 3             -0.486549                            -0.007762
# 4             -0.486549                            -0.007762

# %%
x_rc4_scores_y2,x_rc4_i_y2
# Out:
# (array([6.45517553e+02, 3.98636827e+02, 7.62780350e+02, 9.78239577e+02,
#         1.38092441e+04, 1.34732475e+01, 1.53991345e+04, 1.78360137e+04,
#         3.57068578e+00, 6.34907342e+03, 5.47020146e+02, 5.70383140e+02,
#         5.90568763e+02, 2.06082723e+04, 1.18658132e+04, 8.08299072e+03,
#         1.01269435e+04, 8.80896280e+03, 3.66254028e+03, 1.97752074e+02,
#         1.30711971e+03, 1.11235890e+01, 3.90166699e+02,            nan,
#         1.21989618e+01, 1.84484740e+02, 7.51078382e+03, 1.78975181e+04,
#         6.14528938e+03, 6.72394179e+03, 2.49454202e+03, 8.47170140e+03,
#         4.71868612e+03, 5.36057236e+03, 1.52691016e+03, 2.37692928e+01,
#         2.37692928e+01, 6.00260443e+01, 1.79486762e+02, 1.18911408e+04,
#         4.45401696e+03, 6.96529986e+03, 1.79313616e+04, 1.79313616e+04,
#         1.75926895e+04, 2.77177015e+03, 7.37249943e+03, 2.52958388e+04,
#         8.64560933e+03, 5.26592812e+02, 3.45307177e+03, 2.33296310e+03,
#         5.66486322e+03, 2.21814955e+02, 1.01426330e+04, 1.26062673e+04,
#         3.39192216e+03, 2.27158632e+04, 8.64560886e+03,            nan]),
#  array([ 8, 21, 24,  5, 35, 36, 37, 38, 25, 19, 53, 22,  1, 49, 10, 11, 12,
#          0,  2,  3, 20, 34, 51, 30, 45, 56, 50, 18, 40, 32, 33, 52, 28,  9,
#         29, 41, 46, 26, 15, 31, 58, 48, 17, 16, 54, 14, 39, 55,  4,  6, 44,
#          7, 27, 42, 43, 13, 57, 47, 23, 59]))

# %% [markdown]
# **rural result, y2:**

# %%
scores_desc_rc4_y2=np.flip(x_rc4_scores_y2[x_rc4_i_y2])
cols_desc_rc4_y2=list(x_rc4_scaled.iloc[:3,x_rc4_i_y2].columns) #remove last index?
cols_desc_rc4_y2.reverse()
res_df_rc4_y2=pd.DataFrame({'Variable':cols_desc_rc4_y2,
        'ANOVA corr':scores_desc_rc4_y2}).iloc[2:,:]
# dfi.export(res_df_rc4_y2, '/Users/yapinghe/Desktop/broadband research/ruca_rural_anova_corr_y2.png')
# res_df_rc4_y2.to_csv('ruca_rural_anova_corr_y2.csv')
res_df_rc4_y2
# Out:
#                                           Variable    ANOVA corr
# 2                             Institutional Health  25295.838790
# 3              Confidence in Institutions Subindex  22715.863185
# 4                          pct_Othr_Lang_ACS_14_18  20608.272319
# 5                       Requiring all 4 Subindices  17931.361587
# 6                               County-Level Index  17931.361587
# 7       Population Density (per square mile), 2010  17897.518124
# 8                     pct_NH_White_alone_ACS_14_18  17836.013708
# 9                    Excluding Collective Efficacy  17592.689475
# 10                          pct_Hispanic_ACS_14_18  15399.134517
# 11                   avg_Tot_Prns_in_HHD_ACS_14_18  13809.244064
# 12  Presidential election voting rate, 2012 & 2016  12606.267283
# 13                                        pct_lths  11891.140814
# 14                            pct_ENG_VW_ACS_14_18  11865.813222
# 15              Informal Civic Engagement Subindex  10142.632968
# 16                           pct_College_ACS_14_18  10126.943530
# 17                        avg_Agg_HH_INC_ACS_14_18   8808.962795
# 18                             Collective Efficacy   8645.609333
# 19                        Violent Crimes p 100,000   8645.608860
# 20                                pct_belowpov_raw   8471.701405
# 21                       pct_Not_HS_Grad_ACS_14_18   8082.990718
# 22                  Land Area (square miles), 2010   7510.783817
# 23                                Community Health   7372.499429
# 24                                    pct_bachmore   6965.299862
# 25                                           index   6723.941787
# 26                     pct_NH_AIAN_alone_ACS_14_18   6349.073420
# 27                                            rank   6145.289383
# 28  Non-religious non-profit organizations p 1,000   5664.863217
# 29                                    life_exp_raw   5360.572359
# 30                                 pct_deeppov_raw   4718.686119
# 31                                            lfpr   4454.016960
# 32                   pct_Prs_Blw_Pov_Lev_ACS_14_18   3662.540278
# 33                       % women currently married   3453.071766
# 34                  Mail-back census response rate   3391.922155
# 35                                    Family Unity   2771.770153
# 36                                    mobility_raw   2494.542025
# 37                   % children with single parent   2332.963103
# 38                                         lbw_raw   1526.910162
# 39                   pct_Diff_HU_1yr_Ago_ACS_14_18   1307.119711
# 40                          pct_RURAL_POP_CEN_2010    978.239577
# 41                  pct_URBAN_CLUSTER_POP_CEN_2010    762.780350
# 42                        Tot_Population_ACS_14_18    645.517553
# 43                      pct_NH_SOR_alone_ACS_14_18    590.568763
# 44                    pct_NH_NHOPI_alone_ACS_14_18    570.383140
# 45                    pct_NH_Asian_alone_ACS_14_18    547.020146
# 46                     % births to unmarried women    526.592812
# 47                 pct_URBANIZED_AREA_POP_CEN_2010    398.636827
# 48                   avg_Agg_House_Value_ACS_14_18    390.166699
# 49                 Religious congregations p 1,000    221.814955
# 50                      pct_PUB_ASST_INC_ACS_14_18    197.752074
# 51                          Tract Population, 2010    184.484740
# 52                                         tot_pop    179.486762
# 53                                     reservation     60.026044
# 54                                           rural     23.769293
# 55                                           urban     23.769293
# 56                      pct_Vacant_Units_ACS_14_18     13.473248
# 57          Secondary RUCA Code, 2010 (see errata)     12.198962
# 58                   pct_Recent_Built_HU_ACS_14_18     11.123589
# 59                      pct_NH_Blk_alone_ACS_14_18      3.570686

# %%
# by ruca code (1-3,4-6,7-9,10)?

# %%
# by pct population (US anova result is highest for pct_RURAL_POP_CEN_2010)?

# %%
# plt.hist(df_num_2['pct_RURAL_POP_CEN_2010'],bins=20)

# %%
# df_num_2.describe()['pct_RURAL_POP_CEN_2010']

# %%
# for i in np.arange(0,105,5):
#     print(i,df_num_2['pct_RURAL_POP_CEN_2010'].quantile(i/100))

# %%
# # make a category for 100% rural, 25-99% rural, 0.01-24.99% rural, and 0% rural
# len(df_num_2[df_num_2['pct_RURAL_POP_CEN_2010']==100]), \
# len(df_num_2[(df_num_2['pct_RURAL_POP_CEN_2010'] >= 25) & (df_num_2['pct_RURAL_POP_CEN_2010'] <100)]) ,\
# len(df_num_2[(df_num_2['pct_RURAL_POP_CEN_2010'] >0) & (df_num_2['pct_RURAL_POP_CEN_2010'] <25)]), \
# len(df_num_2[df_num_2['pct_RURAL_POP_CEN_2010']==0])
# # rur_u5=df_num_2[df_num_2['ruca_cat']==1] #under 5% rural
# # rc2=df_num_2[df_num_2['ruca_cat']==2] # 5 to 
# # rc3=df_num_2[df_num_2['ruca_cat']==3] #exurb
# # rc4=df_num_2[df_num_2['ruca_cat']==4] #rural
# # len(rc1),len(rc2),len(rc3),len(rc4)
